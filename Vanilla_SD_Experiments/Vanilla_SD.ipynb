# %%
#!pip install torchviz
# !pip install tsf


import h5py
import json
import matplotlib.pyplot as plt
import numpy as np
import numpy
import statistics
from numpy import loadtxt
import matplotlib.pyplot as plt
import pandas
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from statistics import stdev
import math
# import h5py

import numpy as np
import time

from scipy.signal import butter,filtfilt
import sys
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph
import seaborn as sns # used for plot interactive graph.
import pandas
import matplotlib.pyplot as plt

# from tsf.model import TransformerForecaster


# from tensorflow.keras.utils import np_utils
import itertools
###  Library for attention layers
import pandas as pd
import os
import numpy as np
#from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split

import statistics
import gc
import torch.nn.init as init

############################################################################################################################################################################
############################################################################################################################################################################

import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.nn.utils.weight_norm as weight_norm
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Dataset
import torch.nn.functional as F
#from torchsummary import summary
from torch.nn.parameter import Parameter

#from torchsummary import summary



import torch.optim as optim
import gc

from tqdm.notebook import tqdm
from sklearn.preprocessing import MinMaxScaler, StandardScaler


from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/Mydrive/datacollection/vicon"

# %%
#to delete data produced by datasharding function
import shutil
import os

yes_delete = False

if yes_delete:
    # Example path to the folder you want to delete
    folder_path = '/content/datasets'
    # Delete the folder and its contents recursively
    shutil.rmtree(folder_path)

# %% [markdown]
# # File path

# %% [markdown]
# # Data loader

# %%
# Index 0: pelvis_tilt
# Index 1: pelvis_list
# Index 2: pelvis_rotation
# Index 3: pelvis_tx
# Index 4: pelvis_ty
# Index 5: pelvis_tz
# Index 6: hip_flexion_r
# Index 7: hip_adduction_r
# Index 8: hip_rotation_r
# Index 9: knee_angle_r
# Index 10: knee_angle_r_beta
# Index 11: ankle_angle_r
# Index 12: subtalar_angle_r
# Index 13: mtp_angle_r
# Index 14: hip_flexion_l
# Index 15: hip_adduction_l
# Index 16: hip_rotation_l
# Index 17: knee_angle_l
# Index 18: knee_angle_l_beta
# Index 19: ankle_angle_l
# Index 20: subtalar_angle_l
# Index 21: mtp_angle_l
# Index 22: lumbar_extension
# Index 23: lumbar_bending
# Index 24: lumbar_rotation
# Index 25: arm_flex_r
# Index 26: arm_add_r
# Index 27: arm_rot_r
# Index 28: elbow_flex_r
# Index 29: pro_sup_r
# Index 30: wrist_flex_r
# Index 31: wrist_dev_r
# Index 32: arm_flex_l
# Index 33: arm_add_l
# Index 34: arm_rot_l
# Index 35: elbow_flex_l
# Index 36: pro_sup_l
# Index 37: wrist_flex_l
# Index 38: wrist_dev_l
# Index 39: time
# Index 40: 1
# Index 41: IM EMG1
# Index 42: IM EMG2
# Index 43: IM EMG3
# Index 44: IM EMG4
# Index 45: IM EMG5
# Index 46: IM EMG6
# Index 47: IM EMG7
# Index 48: IM EMG8
# Index 49: ACCX1
# Index 50: ACCY1
# Index 51: ACCZ1
# Index 52: GYROX1
# Index 53: GYROY1
# Index 54: GYROZ1
# Index 55: ACCX2
# Index 56: ACCY2
# Index 57: ACCZ2
# Index 58: GYROX2
# Index 59: GYROY2
# Index 60: GYROZ2
# Index 61: ACCX3
# Index 62: ACCY3
# Index 63: ACCZ3
# Index 64: GYROX3
# Index 65: GYROY3
# Index 66: GYROZ3
# Index 67: ACCX4
# Index 68: ACCY4
# Index 69: ACCZ4
# Index 70: GYROX4
# Index 71: GYROY4
# Index 72: GYROZ4
# Index 73: ACCX5
# Index 74: ACCY5
# Index 75: ACCZ5
# Index 76: GYROX5
# Index 77: GYROY5
# Index 78: GYROZ5
# Index 79: ACCX6
# Index 80: ACCY6
# Index 81: ACCZ6
# Index 82: GYROX6
# Index 83: GYROY6
# Index 84: GYROZ6
# Index 85: ACCX7
# Index 86: ACCY7
# Index 87: ACCZ7
# Index 88: GYROX7
# Index 89: GYROY7
# Index 90: GYROZ7
# Index 91: ACCX8
# Index 92: ACCY8
# Index 93: ACCZ8
# Index 94: GYROX8
# Index 95: GYROY8
# Index 96: GYROZ8

columns_imu_acc = ['ACCX1', 'ACCY1', 'ACCZ1','ACCX2', 'ACCY2', 'ACCZ2','ACCX3', 'ACCY3', 'ACCZ3','ACCX4', 'ACCY4', 'ACCZ4','ACCX5', 'ACCY5', 'ACCZ5', 'ACCX6', 'ACCY6', 'ACCZ6','ACCX8', 'ACCY8', 'ACCZ8']

#made due to difference in subject 1 and subject 2 data
columns_imu_acc_test = ['ACCX1', 'ACCY1', 'ACCZ1','ACCX2', 'ACCY2', 'ACCZ2','ACCX3', 'ACCY3', 'ACCZ3','ACCX4', 'ACCY4', 'ACCZ4','ACCX5', 'ACCY5', 'ACCZ5', 'ACCX6', 'ACCY6', 'ACCZ6','ACCX10', 'ACCY10', 'ACCZ10']

columns_imu_gyr = ['GYROX1', 'GYROY1', 'GYROZ1','GYROX2', 'GYROY2', 'GYROZ2','GYROX3', 'GYROY3', 'GYROZ3','GYROX4', 'GYROY4', 'GYROZ4','GYROX5', 'GYROY5', 'GYROZ5', 'GYROX6', 'GYROY6', 'GYROZ6', 'GYROX8', 'GYROY8', 'GYROZ8']

#made due to difference in subject 1 and subject 2 data
columns_imu_gyr_test = ['GYROX1', 'GYROY1', 'GYROZ1','GYROX2', 'GYROY2', 'GYROZ2', 'GYROX3', 'GYROY3', 'GYROZ3','GYROX4', 'GYROY4', 'GYROZ4','GYROX5', 'GYROY5', 'GYROZ5', 'GYROX6', 'GYROY6', 'GYROZ6', 'GYROX10', 'GYROY10', 'GYROZ10']

columns_joints = ['elbow_flex_r', 'arm_flex_r', 'arm_add_r']

# %%
#CONFIG

class config_general:
    #device = 'cuda' if torch.cuda.is_available() else 'cpu'

    def __init__(self, **kwargs):
        self.batch_size = kwargs.get('batch_size', 16)
        self.epochs = kwargs.get('epochs', 10)
        self.lr = kwargs.get('lr', 0.001)
        self.scheduler = kwargs.get('scheduler', None)
        self.channels_imu_acc = kwargs.get('channels_imu_acc', None)
        self.channels_imu_acc_test = kwargs.get('channels_imu_acc_test', None)
        self.channels_imu_gyr_test = kwargs.get('channels_imu_gyr_test', None)
        self.channels_imu_gyr = kwargs.get('channels_imu_gyr', None)
        self.channels_joints = kwargs.get('channels_joints', None)
        self.channels_emg = kwargs.get('channels_emg', None)
        self.num_sessions = kwargs.get('num_sessions', None)
        self.num_patients = kwargs.get('num_patients', None)
        self.seed = kwargs.get('seed', 42)
        self.data_folder_name = kwargs.get('data_folder_name', 'default_data_folder_name')
        self.dataset_root = kwargs.get('dataset_root', 'default_dataset_root')
        self.dataset_train_name = kwargs.get('dataset_train_name', 'train')
        self.dataset_test_name = kwargs.get('dataset_test_name', 'test')
        self.dataset_name = kwargs.get('dataset_name', 'default_dataset_name')
        self.window_length = kwargs.get('window_length', 100)
        self.window_overlap = kwargs.get('window_overlap', 0)
        self.imu_transforms = kwargs.get('imu_transforms', [])
        self.joint_transforms = kwargs.get('joint_transforms', [])
        self.emg_transforms = kwargs.get('emg_transforms', [])
        self.hidden_size = kwargs.get('hidden_size', 256)
        self.num_layers = kwargs.get('num_layers', 6)
        self.input_size = kwargs.get('input_size', 3)
        self.output_size = kwargs.get('output_size', 3)
        self.sample_rate =kwargs.get('sample_rate', 100)
        self.input_format =  kwargs.get('input_format', 'vicon') # csv or wav

        hyperparameters = [
            f"batch_size_{self.batch_size}",
            f"epochs_{self.epochs}",
            f"lr_{self.lr}",
            f"scheduler_{self.scheduler}",
            f"channels_imu_gyr_{self.channels_imu_gyr}",
            f"channels_imu_acctest__{self.channels_imu_acc_test}",
            f"channels_imu_acc_{self.channels_imu_acc}",
            f"channels_imu_gyr_test_{self.channels_imu_gyr_test}",
            f"channels_joints_{self.channels_joints}",
            f"channels_emg_{self.channels_emg}",
            f"num_sessions_{self.num_sessions}",
            f"num_patients_{self.num_patients}",
            f"seed_{self.seed}",
            f"data_folder_name_{self.data_folder_name}",
            f"dataset_root_{self.dataset_root}",
            f"dataset_train_name_{self.dataset_train_name}",
            f"dataset_test_name_{self.dataset_test_name}",
            f"window_length_{self.window_length}",
            f"imu_transforms_{self.imu_transforms}",
            f"joint_transforms_{self.joint_transforms}",
            f"emg_transforms_{self.emg_transforms}",
            f"hidden_size_{self.hidden_size}",
            f"num_layers_{self.num_layers}",
            f"input_size_{self.input_size}",
            f"output_size_{self.output_size}",
            f"sample_rate_{self.sample_rate}",
            f"input_format_{self.input_format}"
        ]

        self.hyperparameters_str = "_".join(map(str, hyperparameters))

# %%
#FUNCTION TO RETRIEVE DATA FROM WAV FILES
from scipy.io import wavfile

def get_data_from_wav_file(filename): #return data shape [time_steps,channels]
        sample_rate, data = wavfile.read(filename)
        # print(f"Sample rate: {sample_rate}Hz|Data shape: {data.shape}")
        return data, sample_rate

# %%
#USE CONFIG

config = config_general(
    data_folder_name="/content/drive/MyDrive/datacollection/vicon",
    dataset_root="datasets",
    dataset_name="two_subject_downsampled",
    window_length=100,
    window_overlap=50,
    input_format="csv",
    num_patients=2,
    channels_imu_acc= columns_imu_acc,  # Column name for accelerometer data in CSV
    channels_imu_acc_test=columns_imu_acc_test,  # Column name for accelerometer data in CSV
    channels_imu_gyr_test=columns_imu_gyr_test,  # Column name for gyroscope data in CSV
    channels_imu_gyr=columns_imu_gyr,  # Column name for gyroscope data in CSV
    channels_joints=columns_joints,  # Column name for joint data in CSV
    channels_emg=['IM EMG4', 'IM EMG5', 'IM EMG6'],
    imu_transforms=[],
    joint_transforms=[],
    emg_transforms=[]
)

# %%
#DATASHARDER

class DataSharder:
    def __init__(self, config, save_h5=True):
        self.config = config
        self.sample_rate = config.sample_rate
        self.input_format = config.input_format
        self.data_folder_path = config.data_folder_name
        self.window_length = int(config.window_length)
        self.window_overlap = int(config.window_overlap)
        self.num_patients = int(config.num_patients)
        self.save_h5 = save_h5

    def load_data(self):
        patient_folders_list = [f for f in os.listdir(self.data_folder_path) if os.path.isdir(os.path.join(self.data_folder_path, f))]
        #sort
        patient_folders_list.sort(key=lambda x: int(x.split('_')[-1]))
        training_patients = patient_folders_list[:self.num_patients-1]
        testing_patients = patient_folders_list[-1:]
        print(f"Training patients: {training_patients}")
        print(f"Testing patients: {testing_patients}")

        if self.input_format == 'wav':
            self._process_and_save_patients_wav(training_patients, "train")
            self._process_and_save_patients_wav(testing_patients, "test")
        elif self.input_format == 'csv':
            self._process_and_save_patients_csv(training_patients, "train")
            self._process_and_save_patients_csv(testing_patients, "test")
        else:
            raise ValueError(f"Unsupported input format: {self.input_format}")

    def _process_and_save_patients_wav(self, patient_id_list, split):
        total_data = []
        for patient_id in tqdm(patient_id_list, desc=f"Processing {split} patients"):
            for session_index in tqdm(range(self.config.num_sessions), desc=f"Processing sessions for {patient_id}", leave=False):
                imu_data, imu_sample_rate = self._load_wav_file(patient_id, session_index, "IMU")
                joints_data, joints_sample_rate = self._load_wav_file(patient_id, session_index, "JOINTS")
                emg_data, emg_sample_rate = self._load_wav_file(patient_id, session_index, "EMG")

                imu_data = self._resample_data(imu_data, imu_sample_rate)
                joints_data = self._resample_data(joints_data, joints_sample_rate)
                emg_data = self._resample_data(emg_data, emg_sample_rate)

                combined_data = torch.cat((imu_data, joints_data, emg_data), dim=1)
                total_data.append(combined_data.cpu().numpy())

        if self.save_h5:
            self._save_to_h5(total_data, split)
        else:
            for combined_data in total_data:
                self._save_windowed_data(combined_data, patient_id, session_index, split)

    def _load_wav_file(self, patient_id, session_index, file_type):
        file_path = os.path.join(self.data_folder_path, patient_id, f"run{session_index}_{file_type}.wav")
        data, sample_rate = get_data_from_wav_file(file_path)
        return torch.tensor(data, dtype=torch.float32), sample_rate

    def _resample_data(self, data, sample_rate):
        if sample_rate != self.sample_rate:
            data = T.Resample(sample_rate, self.sample_rate)(data.T).T
        return data

    def _process_and_save_patients_csv(self, patient_id_list, split):
        total_data = []
        column_names = None
        for patient_id in tqdm(patient_id_list, desc=f"Processing {split} patients"):
            patient_files = os.listdir(os.path.join(self.data_folder_path, patient_id, "combined"))
            patient_data = []
            for session_file in tqdm(patient_files, desc=f"Processing sessions for {patient_id}", leave=False):
                data = pd.read_csv(os.path.join(self.data_folder_path, patient_id, "combined", session_file))
                if column_names is None:
                    column_names = data.columns
                patient_data.append(data.to_numpy()[:2900])
            total_data.append(patient_data)


        if self.save_h5:
            self._save_to_h5(total_data, split, column_names)
        else:
            for data in total_data:
                self._save_windowed_data(pd.DataFrame(data, columns=column_names), patient_id, session_file.split('.')[0], split, is_csv=True)

    def _save_windowed_data(self, data, patient_id, session_id, split, is_csv=False):
        dataset_name = f"{self.config.dataset_name}_wl{self.window_length}_ol{self.window_overlap}_np{self.num_patients}"
        dataset_folder = os.path.join(self.config.dataset_root, dataset_name, self.config.dataset_train_name if split == "train" else self.config.dataset_test_name)
        os.makedirs(dataset_folder, exist_ok=True)

        window_size = self.window_length
        overlap = self.window_overlap
        step_size = window_size - overlap

        data_info_list = []

        for i in tqdm(range(0, len(data) - window_size + 1, step_size), desc=f"Windowing data for {patient_id}_{session_id}", leave=False):
            windowed_data = data.iloc[i:i+window_size] if is_csv else data[i:i+window_size]
            if windowed_data.shape[0] < window_size:
                continue

            windowed_data_np = windowed_data.to_numpy() if is_csv else windowed_data.cpu().numpy()

            file_name = f"{patient_id}_session_{session_id}_window_{i}_ws{window_size}_ol{overlap}.csv"
            file_path = os.path.join(dataset_folder, file_name)
            pd.DataFrame(windowed_data_np, columns=data.columns if is_csv else None).to_csv(file_path, index=False)
            data_info_list.append({"file_name": file_name, "file_path": file_path})

        data_info_df = pd.DataFrame(data_info_list)
        data_info_df.to_csv(os.path.join(self.config.dataset_root, dataset_name, f"{split}_info.csv"), index=False, mode='a', header=not os.path.exists(os.path.join(self.config.dataset_root, dataset_name, f"{split}_info.csv")))

    def _save_to_h5(self, data_list, split, column_names=None):
        dataset_name = f"{self.config.dataset_name}_np{self.num_patients}"
        h5_file_path = os.path.join(self.config.dataset_root, dataset_name, f"{split}_data.h5")


        combined_data = np.array(data_list)
        print(combined_data.shape)

        #create ffolder path if it doesnt exist
        os.makedirs(os.path.dirname(h5_file_path), exist_ok=True)

        with h5py.File(h5_file_path, 'w') as h5file:
            h5file.create_dataset(f"{split}_data", data=combined_data)
            if column_names is not None:
                h5file.create_dataset(f"{split}_columns", data=np.array(column_names, dtype='S'))

# %%
#USE DATASHARDER
# !pwd
import torch
import h5py
reshard_data = False
if reshard_data:
    data_sharder = DataSharder(config)
    data_sharder.load_data()
# Out:
# /content

# %% [markdown]
# # Data processing

# %%
class ImuJointPairDataset(Dataset):
    def __init__(self, config, split='train'):
        self.config = config
        self.split = split
        self.input_format = "h5"
        self.channels_imu_acc = config.channels_imu_acc
        self.channels_imu_acc_test = config.channels_imu_acc_test
        self.channels_imu_gyr = config.channels_imu_gyr
        self.channels_imu_gyr_test = config.channels_imu_gyr_test
        self.channels_joints = config.channels_joints
        self.channels_emg = config.channels_emg
        self.window_length = int(config.window_length)
        self.window_overlap = int(config.window_overlap)

        # Load HDF5 file
        h5_file_path = os.path.join(config.dataset_root, f"{config.dataset_name}_np{config.num_patients}", f"{split}_data.h5")

        with h5py.File(h5_file_path, 'r') as h5file:
            data_unfiltered = h5file[split + '_data'][:]
            self.columns = h5file[split + '_columns'][:].astype(str)

        if split == 'train':
            self.accel_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_imu_acc]
            self.gyro_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_imu_gyr]
            self.joint_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_joints]
            self.emg_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_emg]

            self.all_indexes = self.accel_indexes + self.gyro_indexes + self.joint_indexes + self.emg_indexes

            # Save the column names for future use
            self.column_names_path = os.path.join(config.dataset_root, f"{config.dataset_name}_np{config.num_patients}", "column_names.pkl")
            joblib.dump(self.columns[self.all_indexes], self.column_names_path)
        elif split == 'test':
            self.accel_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_imu_acc_test]
            self.gyro_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_imu_gyr_test]
            self.joint_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_joints]
            self.emg_indexes = [i for i, col in enumerate(self.columns) if col in self.channels_emg]
            self.all_indexes = self.accel_indexes + self.gyro_indexes + self.joint_indexes + self.emg_indexes

            self.column_names_path = os.path.join(config.dataset_root, f"{config.dataset_name}_np{config.num_patients}", "column_names.pkl")
            self.columns = joblib.load(self.column_names_path)

        # Filter to only the selected channels
        self.data = data_unfiltered[:, :, :, self.all_indexes]
        print(self.data.shape)

        # Reshape data to [patients * trials * timesteps, channels] format
        reshaped_data = self.data.reshape(-1, self.data.shape[-1])

        # Define the path for saving the scaler
        dataset_name = f"{config.dataset_name}_np{config.num_patients}"
        self.scaler_save_path = os.path.join(config.dataset_root, dataset_name, "scaler.pkl")

        # Load or fit the scaler
        if os.path.exists(self.scaler_save_path) and split == 'test':
            self.scaler = joblib.load(self.scaler_save_path)
        elif split == 'train':
            self.scaler = StandardScaler()
            self.scaler.fit(reshaped_data)
            joblib.dump(self.scaler, self.scaler_save_path)
        else:
            raise FileNotFoundError("Scaler not found. Ensure you run the training split first to fit and save the scaler.")

        # Normalize the data
        self.data = self.scaler.transform(reshaped_data).reshape(self.data.shape)

        # Calculate the number of windows
        total_timesteps = self.data.shape[2]
        window_step = self.window_length - self.window_overlap
        self.num_windows = ((total_timesteps - self.window_length) // window_step + 1) * self.data.shape[0] * self.data.shape[1]

    def __len__(self):
        return self.num_windows

    def __getitem__(self, idx):
        total_timesteps = self.data.shape[2]
        window_step = self.window_length - self.window_overlap

        # Determine the patient and trial index
        windows_per_trial = (total_timesteps - self.window_length) // window_step + 1
        patient_index = idx // (windows_per_trial * self.data.shape[1])
        trial_index = (idx % (windows_per_trial * self.data.shape[1])) // windows_per_trial
        window_index = idx % windows_per_trial

        start_timestep = window_index * window_step
        end_timestep = start_timestep + self.window_length

        # Extract data window for the specific patient and trial
        data_window = self.data[patient_index, trial_index, start_timestep:end_timestep, :]

        # Normalize the data window
        data_window = self.scaler.transform(data_window.reshape(-1, data_window.shape[-1])).reshape(data_window.shape)

        # Split data into respective channels
        imu_data_acc = data_window[:, :len(self.channels_imu_acc)]
        imu_data_gyr = data_window[:, len(self.channels_imu_acc):len(self.channels_imu_acc) + len(self.channels_imu_gyr)]
        joint_data = data_window[:, len(self.channels_imu_acc) + len(self.channels_imu_gyr):len(self.channels_imu_acc) + len(self.channels_imu_gyr) + len(self.channels_joints)]
        emg_data = data_window[:, len(self.channels_imu_acc) + len(self.channels_imu_gyr) + len(self.channels_joints):]

        # Apply transformations
        imu_data_acc = self.apply_transforms(imu_data_acc)
        imu_data_gyr = self.apply_transforms(imu_data_gyr)
        joint_data = self.apply_transforms(joint_data)
        emg_data = self.apply_transforms(emg_data)

        return imu_data_acc, imu_data_gyr, joint_data, emg_data

    # Function to apply transforms
    def apply_transforms(self, data):
        data = ToTensor()(data).squeeze(0)
        return data

# %%
import joblib

from torchvision.transforms import ToTensor

#create datasets
train_dataset = ImuJointPairDataset(config, split='train')
print(train_dataset.__getitem__(0)[0].shape, train_dataset.__getitem__(0)[1].shape, train_dataset.__getitem__(0)[2].shape, train_dataset.__getitem__(0)[3].shape)
test_dataset = ImuJointPairDataset(config, split='test')
print(test_dataset.__getitem__(0)[0].shape, test_dataset.__getitem__(0)[1].shape, test_dataset.__getitem__(0)[2].shape, test_dataset.__getitem__(0)[3].shape)
# Out:
# (1, 15, 2900, 48)
# torch.Size([100, 21]) torch.Size([100, 21]) torch.Size([100, 3]) torch.Size([100, 3])
# (1, 16, 2900, 48)
# torch.Size([100, 21]) torch.Size([100, 21]) torch.Size([100, 3]) torch.Size([100, 3])

# %%
#setup validation dataset
train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.1, random_state=42)

# %%
#setup dataloaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Get the first batch from the train loader
data_acc, data_gyr, data_targets, data_emg = next(iter(train_loader))

print(f"Data shape: {data_acc.shape}, {data_gyr.shape}, {data_targets.shape}, {data_emg.shape}")

# Plot the first element in the train loader
#plot_data_kinelight(x, y, config, test_dataset.scaler, "Train")

# Optionally, plot the first element in the test loader
#x_test, y_test = next(iter(test_loader))
#plot_data_kinelight(x_test, y_test, config, test_dataset.scaler, "Test")
# Out:
# Data shape: torch.Size([64, 100, 21]), torch.Size([64, 100, 21]), torch.Size([64, 100, 3]), torch.Size([64, 100, 3])

# %% [markdown]
# # Important Functions

# %%
#prediction function
def RMSE_prediction(yhat_4,test_y, output_dim):

  s1=yhat_4.shape[0]*yhat_4.shape[1]

  test_o=test_y.reshape((s1,output_dim))
  yhat=yhat_4.reshape((s1,output_dim))




  y_1_no=yhat[:,0]
  y_2_no=yhat[:,1]
  y_3_no=yhat[:,2]
  #y_4_no=yhat[:,3]
  #y_5_no=yhat[:,4]
  #y_6_no=yhat[:,5]
  #y_7_no=yhat[:,6]
  #y_8_no=yhat[:,7]
  #y_9_no=yhat[:,8]
  #y_10_no=yhat[:,9]


  y_1=y_1_no
  y_2=y_2_no
  y_3=y_3_no
  #y_4=y_4_no
  #y_5=y_5_no
  #y_6=y_6_no
  #y_7=y_7_no



  y_test_1=test_o[:,0]
  y_test_2=test_o[:,1]
  y_test_3=test_o[:,2]
  #y_test_4=test_o[:,3]
  #y_test_5=test_o[:,4]
  #y_test_6=test_o[:,5]
  #y_test_7=test_o[:,6]
  #y_test_8=test_o[:,7]
  #y_test_9=test_o[:,8]
  #y_test_10=test_o[:,9]





  #print(y_1.shape,y_test_1.shape)


  cutoff=6
  fs=200
  order=4

  nyq = 0.5 * fs
  ## filtering data ##
  def butter_lowpass_filter(data, cutoff, fs, order):
      normal_cutoff = cutoff / nyq
      # Get the filter coefficients
      b, a = butter(order, normal_cutoff, btype='low', analog=False)
      y = filtfilt(b, a, data)
      return y



  # y_1=butter_lowpass_filter(y_1_no, cutoff, fs, order)
  # y_2=butter_lowpass_filter(y_2_no, cutoff, fs, order)
  # y_3=butter_lowpass_filter(y_3_no, cutoff, fs, order)
  # y_4=butter_lowpass_filter(y_4_no, cutoff, fs, order)
  # y_5=butter_lowpass_filter(y_5_no, cutoff, fs, order)
  # y_6=butter_lowpass_filter(y_6_no, cutoff, fs, order)
  # y_7=butter_lowpass_filter(y_7_no, cutoff, fs, order)
  #y_8=butter_lowpass_filter(y_8_no, cutoff, fs, order)
  #y_9=butter_lowpass_filter(y_9_no, cutoff, fs, order)
  #y_10=butter_lowpass_filter(y_10_no, cutoff, fs, order)




  Z_1=y_1
  Z_2=y_2
  Z_3=y_3
  #Z_4=y_4
  #Z_5=y_5
  #Z_6=y_6
  #Z_7=y_7
  #Z_8=y_8
  #Z_9=y_9
  #Z_10=y_10



  ###calculate RMSE

  rmse_1 =((np.sqrt(mean_squared_error(y_test_1,y_1)))/(max(y_test_1)-min(y_test_1)))*100
  rmse_2 =((np.sqrt(mean_squared_error(y_test_2,y_2)))/(max(y_test_2)-min(y_test_2)))*100
  rmse_3 =((np.sqrt(mean_squared_error(y_test_3,y_3)))/(max(y_test_3)-min(y_test_3)))*100
  #rmse_4 =((np.sqrt(mean_squared_error(y_test_4,y_4)))/(max(y_test_4)-min(y_test_4)))*100
  #rmse_5 =((np.sqrt(mean_squared_error(y_test_5,y_5)))/(max(y_test_5)-min(y_test_5)))*100
  #rmse_6 =((np.sqrt(mean_squared_error(y_test_6,y_6)))/(max(y_test_6)-min(y_test_6)))*100
  #rmse_7 =((np.sqrt(mean_squared_error(y_test_7,y_7)))/(max(y_test_7)-min(y_test_7)))*100
  #rmse_8 =((np.sqrt(mean_squared_error(y_test_8,y_8)))/(max(y_test_8)-min(y_test_8)))*100
  #rmse_9 =((np.sqrt(mean_squared_error(y_test_9,y_9)))/(max(y_test_9)-min(y_test_9)))*100
  #rmse_10 =((np.sqrt(mean_squared_error(y_test_10,y_10)))/(max(y_test_10)-min(y_test_10)))*100


  print(rmse_1)
  print(rmse_2)
  print(rmse_3)
  #print(rmse_4)
  #print(rmse_5)
  #print(rmse_6)
  #print(rmse_7)
  #print(rmse_8)
  #print(rmse_9)
  #print(rmse_10)


  p_1=np.corrcoef(y_1, y_test_1)[0, 1]
  p_2=np.corrcoef(y_2, y_test_2)[0, 1]
  p_3=np.corrcoef(y_3, y_test_3)[0, 1]
  #p_4=np.corrcoef(y_4, y_test_4)[0, 1]
  #p_5=np.corrcoef(y_5, y_test_5)[0, 1]
  #p_6=np.corrcoef(y_6, y_test_6)[0, 1]
  #p_7=np.corrcoef(y_7, y_test_7)[0, 1]
  #p_8=np.corrcoef(y_8, y_test_8)[0, 1]
  #p_9=np.corrcoef(y_9, y_test_9)[0, 1]
  #p_10=np.corrcoef(y_10, y_test_10)[0, 1]


  print("\n")
  print(p_1)
  print(p_2)
  print(p_3)
  #print(p_4)
  #print(p_5)
  #print(p_6)
  #print(p_7)
  #print(p_8)
  #print(p_9)
  #print(p_10)


              ### Correlation ###
  p=np.array([p_1,p_2,p_3])
  #,p_4,p_5,p_6,p_7])




      #### Mean and standard deviation ####

  rmse=np.array([rmse_1,rmse_2,rmse_3])
  #,rmse_4,rmse_5,rmse_6,rmse_7])

      #### Mean and standard deviation ####
  m=statistics.mean(rmse)
  SD=statistics.stdev(rmse)
  print('Mean: %.3f' % m,'+/- %.3f' %SD)

  m_c=statistics.mean(p)
  SD_c=statistics.stdev(p)
  print('Mean: %.3f' % m_c,'+/- %.3f' %SD_c)



  return rmse, p, Z_1,Z_2,Z_3
  #,Z_4,Z_5,Z_6,Z_7



############################################################################################################################################################################################################################################################################################################################################################################################################################################################################

# %%
#RMSELoss
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()

    def forward(self, pred, target):
        mse = nn.MSELoss()(pred, target)
        rmse = torch.sqrt(mse)
        return rmse

# %%
#DEVICE
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()

# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Teacher Model Training -- IMU-EMG

# %% [markdown]
# ## Training Function

# %%
import torch
import time
import matplotlib.pyplot as plt

def train_mm_teacher(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            output, x_1 = model(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())
            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for (data_acc, data_gyr, target, data_EMG) in val_loader:
                output, x_1 = model(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Teacher Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
#variable w needs to be checked for correct value, stand-in value used
class teacher(nn.Module):
    def __init__(self, input_acc, input_gyr, input_emg, drop_prob=0.25, w=100):
        super(teacher, self).__init__()

        self.w=w
        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)
        self.encoder_1_emg=Encoder_1(input_emg, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)
        self.encoder_2_emg=Encoder_2(input_emg, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)
        self.BN_emg= nn.BatchNorm1d(input_emg, affine=False)


        self.fc = nn.Linear(2*3*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)
        self.gate_3=GatingModule(128)

        self.fc_kd = nn.Linear(3*128, 2*128)

               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(3*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*3, 3*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*3*128+128, 2*3*128+128), nn.Sigmoid())

        self.pool = nn.MaxPool1d(kernel_size=2)


    def forward(self, x_acc, x_gyr, x_emg):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))
        x_emg_1=x_emg.view(x_emg.size(0)*x_emg.size(1),x_emg.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)
        x_emg_1=self.BN_emg(x_emg_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))
        x_emg_2=x_emg_1.view(-1, self.w, x_emg_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)
        x_emg_1=self.encoder_1_emg(x_emg_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)
        x_emg_2=self.encoder_2_emg(x_emg_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)
        # x_emg=torch.cat((x_emg_1,x_emg_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)
        x_emg=self.gate_3(x_emg_1,x_emg_2)

        x=torch.cat((x_acc,x_gyr,x_emg),dim=-1)
        x_kd=self.fc_kd(x)


        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        weights_3 = self.weighted_feat(x[:,:,2*128:3*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        x_3=weights_3*x[:,:,2*128:3*128]
        out_3=x_1+x_2+x_3

        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        #print(out.shape)
        return out,x_kd

# %%
lr = 0.001
model = teacher(21,21,3)

mm_teacher = train_mm_teacher(device, train_loader, val_loader, lr,40, model, filename ='model_teacher.pth')
# Out:
# Epoch: 1, time: 0.9618, Training Loss: 0.7385, Validation Loss: 0.4864
# Epoch: 2, time: 0.8995, Training Loss: 0.2040, Validation Loss: 0.3032
# Epoch: 3, time: 0.9062, Training Loss: 0.0933, Validation Loss: 0.2049
# Epoch: 4, time: 0.9014, Training Loss: 0.0560, Validation Loss: 0.0631
# Epoch: 5, time: 0.8883, Training Loss: 0.0397, Validation Loss: 0.0904
# Epoch: 6, time: 0.8812, Training Loss: 0.0442, Validation Loss: 0.0689
# Epoch: 7, time: 0.8892, Training Loss: 0.0375, Validation Loss: 0.0582
# Epoch: 8, time: 0.8820, Training Loss: 0.0430, Validation Loss: 0.0272
# Epoch: 9, time: 0.8838, Training Loss: 0.0308, Validation Loss: 0.0432
# Epoch: 10, time: 0.8857, Training Loss: 0.0340, Validation Loss: 0.0442
# Epoch: 11, time: 0.8833, Training Loss: 0.0460, Validation Loss: 0.0962
# Epoch: 12, time: 0.8852, Training Loss: 0.0588, Validation Loss: 0.0465
# Epoch: 13, time: 0.9032, Training Loss: 0.0344, Validation Loss: 0.0451
# Epoch: 14, time: 0.8870, Training Loss: 0.0294, Validation Loss: 0.0472
# Epoch: 15, time: 0.8906, Training Loss: 0.0415, Validation Loss: 0.0680
# Epoch: 16, time: 0.9050, Training Loss: 0.0882, Validation Loss: 0.0285
# Epoch: 17, time: 0.9139, Training Loss: 0.0415, Validation Loss: 0.1063
# Epoch: 18, time: 0.9131, Training Loss: 0.0823, Validation Loss: 0.0384
# Stopping early after 18 epochs
# Training time: 16.49769401550293 seconds

# %%
mm_teacher= teacher(21,21,3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)

mm_teacher.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, ( data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        output,x_1= mm_teacher(data_acc.to(device).float(),data_gyr.to(device).float(),  data_EMG.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

#fix
rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target, output_dim=3)
#,Z_4,Z_5,Z_6,Z_7

ablation_1=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 22.444963504342095
# 22.960529587316916
# 46.94534504049546
#
#
# 0.49513746014443716
# -0.019541338325693897
# 0.06802415826168981
# Mean: 30.784 +/- 13.999
# Mean: 0.181 +/- 0.275

# %% [markdown]
# # Student Model-- 1 IMU

# %% [markdown]
# ## Training Function

# %%
def train_mm_student_1(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            output = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())
            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                output = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_1(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_1, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)

               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_1(3,3)

mm_student_1 = train_mm_student_1(device, train_loader, val_loader, lr,40,model,'model_student_1.pth')
# Out:
# Epoch: 1, time: 0.8779, Training Loss: 0.7121, Validation Loss: 0.3205
# Epoch: 2, time: 0.5539, Training Loss: 0.1628, Validation Loss: 0.0625
# Epoch: 3, time: 0.5600, Training Loss: 0.0856, Validation Loss: 0.0569
# Epoch: 4, time: 0.5621, Training Loss: 0.0531, Validation Loss: 0.0404
# Epoch: 5, time: 0.5840, Training Loss: 0.0421, Validation Loss: 0.0663
# Epoch: 6, time: 0.5727, Training Loss: 0.0534, Validation Loss: 0.0419
# Epoch: 7, time: 0.5806, Training Loss: 0.0463, Validation Loss: 0.0662
# Epoch: 8, time: 0.5898, Training Loss: 0.0569, Validation Loss: 0.0592
# Epoch: 9, time: 0.5860, Training Loss: 0.0435, Validation Loss: 0.0565
# Epoch: 10, time: 0.5911, Training Loss: 0.0374, Validation Loss: 0.0508
# Epoch: 11, time: 0.5828, Training Loss: 0.0470, Validation Loss: 0.0425
# Epoch: 12, time: 0.5708, Training Loss: 0.0469, Validation Loss: 0.0375
# Epoch: 13, time: 0.5609, Training Loss: 0.0405, Validation Loss: 0.0398
# Epoch: 14, time: 0.5669, Training Loss: 0.0433, Validation Loss: 0.0360
# Epoch: 15, time: 0.5630, Training Loss: 0.0393, Validation Loss: 0.0337
# Epoch: 16, time: 0.5656, Training Loss: 0.0387, Validation Loss: 0.0667
# Epoch: 17, time: 0.5667, Training Loss: 0.0376, Validation Loss: 0.0342
# Epoch: 18, time: 0.5623, Training Loss: 0.0300, Validation Loss: 0.0301
# Epoch: 19, time: 0.5639, Training Loss: 0.0307, Validation Loss: 0.0291
# Epoch: 20, time: 0.5702, Training Loss: 0.0345, Validation Loss: 0.0305
# Epoch: 21, time: 0.5672, Training Loss: 0.0415, Validation Loss: 0.0589
# Epoch: 22, time: 0.5666, Training Loss: 0.0526, Validation Loss: 0.0353
# Epoch: 23, time: 0.5700, Training Loss: 0.0304, Validation Loss: 0.0816
# Epoch: 24, time: 0.5694, Training Loss: 0.0529, Validation Loss: 0.0452
# Epoch: 25, time: 0.5693, Training Loss: 0.0355, Validation Loss: 0.0618
# Epoch: 26, time: 0.5728, Training Loss: 0.0337, Validation Loss: 0.0339
# Epoch: 27, time: 0.5714, Training Loss: 0.0282, Validation Loss: 0.0487
# Epoch: 28, time: 0.5711, Training Loss: 0.0403, Validation Loss: 0.0282
# Epoch: 29, time: 0.5784, Training Loss: 0.0345, Validation Loss: 0.0219
# Epoch: 30, time: 0.5986, Training Loss: 0.0241, Validation Loss: 0.0334
# Epoch: 31, time: 0.5890, Training Loss: 0.0275, Validation Loss: 0.0446
# Epoch: 32, time: 0.5903, Training Loss: 0.0382, Validation Loss: 0.0222
# Epoch: 33, time: 0.5914, Training Loss: 0.0259, Validation Loss: 0.0286
# Epoch: 34, time: 0.5930, Training Loss: 0.0353, Validation Loss: 0.0318
# Epoch: 35, time: 0.5856, Training Loss: 0.0369, Validation Loss: 0.0362
# Epoch: 36, time: 0.5782, Training Loss: 0.0358, Validation Loss: 0.0249
# Epoch: 37, time: 0.5826, Training Loss: 0.0340, Validation Loss: 0.0285
# Epoch: 38, time: 0.5742, Training Loss: 0.0274, Validation Loss: 0.0266
# Epoch: 39, time: 0.5795, Training Loss: 0.0293, Validation Loss: 0.0240
# Stopping early after 39 epochs
# Training time: 23.032262802124023 seconds

# %%
mm_student_1= student_1(3,3)
mm_student_1.load_state_dict(torch.load('model_student_1.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, ( data_acc, data_gyr,  target, data_EMG) in enumerate(test_loader):
        output = mm_student_1(data_acc[:,:,0:3].to(device).float(),data_gyr[:,:,0:3].to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

#fix
rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target, output_dim=3)

ablation_2=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 25.87274996508966
# 20.803504187135143
# 38.252589766319
#
#
# 0.3910626673368102
# -0.05580203423710342
# 0.37839695720462174
# Mean: 28.310 +/- 8.976
# Mean: 0.238 +/- 0.254

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
"""## Knowledge distillation"""

def train_student_1(device, alpha, beta, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            student_output, x_student_1 = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                output, student_1 = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_1_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_1_KD, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)



               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_1_KD(3,3)

teacher_trained= teacher(21,21,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)
alpha=0.01
beta=0.01

student_KD= train_student_1(device, alpha, beta, train_loader, val_loader, lr,40, student, 'student_1_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 0.9130, Training Loss: 0.7134, Validation Loss: 0.3456
# Epoch: 2, time: 0.9092, Training Loss: 0.1794, Validation Loss: 0.1835
# Epoch: 3, time: 0.9063, Training Loss: 0.1155, Validation Loss: 0.0929
# Epoch: 4, time: 0.9138, Training Loss: 0.0714, Validation Loss: 0.0504
# Epoch: 5, time: 0.9145, Training Loss: 0.0523, Validation Loss: 0.0379
# Epoch: 6, time: 0.9115, Training Loss: 0.0449, Validation Loss: 0.0368
# Epoch: 7, time: 0.9124, Training Loss: 0.0380, Validation Loss: 0.0403
# Epoch: 8, time: 0.9308, Training Loss: 0.0421, Validation Loss: 0.0387
# Epoch: 9, time: 0.9399, Training Loss: 0.0422, Validation Loss: 0.0633
# Epoch: 10, time: 0.9420, Training Loss: 0.0434, Validation Loss: 0.0433
# Epoch: 11, time: 0.9395, Training Loss: 0.0421, Validation Loss: 0.0369
# Epoch: 12, time: 0.9182, Training Loss: 0.0340, Validation Loss: 0.0593
# Epoch: 13, time: 0.9107, Training Loss: 0.0412, Validation Loss: 0.0289
# Epoch: 14, time: 0.9030, Training Loss: 0.0333, Validation Loss: 0.0614
# Epoch: 15, time: 0.8976, Training Loss: 0.0426, Validation Loss: 0.0597
# Epoch: 16, time: 0.9016, Training Loss: 0.0356, Validation Loss: 0.0376
# Epoch: 17, time: 0.9140, Training Loss: 0.0300, Validation Loss: 0.0708
# Epoch: 18, time: 0.8938, Training Loss: 0.0469, Validation Loss: 0.0318
# Epoch: 19, time: 0.8995, Training Loss: 0.0313, Validation Loss: 0.0316
# Epoch: 20, time: 0.8987, Training Loss: 0.0305, Validation Loss: 0.0261
# Epoch: 21, time: 0.8965, Training Loss: 0.0287, Validation Loss: 0.0386
# Epoch: 22, time: 0.8985, Training Loss: 0.0436, Validation Loss: 0.0562
# Epoch: 23, time: 0.9177, Training Loss: 0.0420, Validation Loss: 0.0280
# Epoch: 24, time: 0.9187, Training Loss: 0.0273, Validation Loss: 0.0938
# Epoch: 25, time: 0.9334, Training Loss: 0.0497, Validation Loss: 0.0713
# Epoch: 26, time: 0.9268, Training Loss: 0.0473, Validation Loss: 0.0521
# Epoch: 27, time: 0.9076, Training Loss: 0.0423, Validation Loss: 0.0275
# Epoch: 28, time: 0.8983, Training Loss: 0.0317, Validation Loss: 0.0320
# Epoch: 29, time: 0.8938, Training Loss: 0.0363, Validation Loss: 0.0493
# Epoch: 30, time: 0.8889, Training Loss: 0.0372, Validation Loss: 0.0426
# Stopping early after 30 epochs
# Training time: 27.584280490875244 seconds

# %%
mm_student_1= student_1_KD(3,3)
mm_student_1.load_state_dict(torch.load('student_1_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, ( data_acc, data_gyr,  target,data_EMG) in enumerate(test_loader):
        output,student_1 = mm_student_1(data_acc[:,:,0:3].to(device).float(),data_gyr[:,:,0:3].to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, data_EMG, target,output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_3=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 51.06169011230032
# 26.768646240120813
# 76.09156926737917
#
#
# 0.19126718972185228
# -0.03650776933954384
# 0.11697822158757343
# Mean: 51.307 +/- 24.662
# Mean: 0.091 +/- 0.116

# %% [markdown]
# # Student Model-- 2 IMUs

# %% [markdown]
# ## Training Function

# %%
def train_mm_student_2(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
            data_gyr = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
            output = model(data_acc.to(device).float(), data_gyr.to(device).float())

            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
                data_gyr = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
                output = model(data_acc.to(device).float(), data_gyr.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_2(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_2, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


        # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_2(6,6)

mm_student_2 = train_mm_student_2(device, train_loader, val_loader, lr,40,model,'model_student_2.pth')
# Out:
# Epoch: 1, time: 0.5647, Training Loss: 0.7206, Validation Loss: 0.3124
# Epoch: 2, time: 0.5666, Training Loss: 0.1632, Validation Loss: 0.0787
# Epoch: 3, time: 0.5624, Training Loss: 0.0884, Validation Loss: 0.0419
# Epoch: 4, time: 0.5664, Training Loss: 0.0434, Validation Loss: 0.0570
# Epoch: 5, time: 0.5615, Training Loss: 0.0462, Validation Loss: 0.0404
# Epoch: 6, time: 0.5670, Training Loss: 0.0335, Validation Loss: 0.0397
# Epoch: 7, time: 0.5641, Training Loss: 0.0357, Validation Loss: 0.0472
# Epoch: 8, time: 0.5657, Training Loss: 0.0373, Validation Loss: 0.0542
# Epoch: 9, time: 0.5634, Training Loss: 0.0337, Validation Loss: 0.0260
# Epoch: 10, time: 0.5623, Training Loss: 0.0455, Validation Loss: 0.0386
# Epoch: 11, time: 0.5769, Training Loss: 0.0496, Validation Loss: 0.0422
# Epoch: 12, time: 0.5866, Training Loss: 0.0455, Validation Loss: 0.0510
# Epoch: 13, time: 0.5923, Training Loss: 0.0350, Validation Loss: 0.0587
# Epoch: 14, time: 0.5741, Training Loss: 0.0480, Validation Loss: 0.0299
# Epoch: 15, time: 0.5894, Training Loss: 0.0258, Validation Loss: 0.0193
# Epoch: 16, time: 0.5846, Training Loss: 0.0253, Validation Loss: 0.0318
# Epoch: 17, time: 0.5851, Training Loss: 0.0300, Validation Loss: 0.0302
# Epoch: 18, time: 0.5729, Training Loss: 0.0510, Validation Loss: 0.0353
# Epoch: 19, time: 0.5619, Training Loss: 0.0711, Validation Loss: 0.0998
# Epoch: 20, time: 0.5592, Training Loss: 0.0640, Validation Loss: 0.0172
# Epoch: 21, time: 0.5603, Training Loss: 0.0235, Validation Loss: 0.0355
# Epoch: 22, time: 0.5638, Training Loss: 0.0269, Validation Loss: 0.0405
# Epoch: 23, time: 0.5646, Training Loss: 0.0378, Validation Loss: 0.0176
# Epoch: 24, time: 0.5637, Training Loss: 0.0356, Validation Loss: 0.0613
# Epoch: 25, time: 0.5624, Training Loss: 0.0639, Validation Loss: 0.0923
# Epoch: 26, time: 0.5641, Training Loss: 0.0653, Validation Loss: 0.0760
# Epoch: 27, time: 0.5558, Training Loss: 0.0761, Validation Loss: 0.0465
# Epoch: 28, time: 0.5634, Training Loss: 0.0321, Validation Loss: 0.0246
# Epoch: 29, time: 0.5650, Training Loss: 0.0300, Validation Loss: 0.0196
# Epoch: 30, time: 0.5611, Training Loss: 0.0252, Validation Loss: 0.0573
# Stopping early after 30 epochs
# Training time: 17.267938375473022 seconds

# %%
mm_student_2= student_2(6,6)
mm_student_2.load_state_dict(torch.load('model_student_2.pth'))
mm_student_2.to(device)

mm_student_2.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:3],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:3],data_gyr[:,:,9:12]),dim=-1)
        output = mm_student_2(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_4=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 31.924038329356204
# 19.718249887090156
# 32.34196142215625
#
#
# 0.4881148823480413
# 0.3700101117340602
# 0.49625112060156723
# Mean: 27.995 +/- 7.171
# Mean: 0.451 +/- 0.071

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
def train_student_2(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc_1 = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
            data_gyr_1 = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
            student_output, x_student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc_1 = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
                data_gyr_1 = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
                output, student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_2_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_2_KD, self).__init__()
        self.w=w
        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_2_KD(6,6)

teacher_trained= teacher(21,21,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)


student_KD= train_student_2(device, train_loader, val_loader, lr,40, student, 'student_2_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 0.8880, Training Loss: 0.7028, Validation Loss: 0.2383
# Epoch: 2, time: 0.8949, Training Loss: 0.1425, Validation Loss: 0.0829
# Epoch: 3, time: 0.9254, Training Loss: 0.0830, Validation Loss: 0.0583
# Epoch: 4, time: 0.9121, Training Loss: 0.0522, Validation Loss: 0.0438
# Epoch: 5, time: 0.9293, Training Loss: 0.0461, Validation Loss: 0.0506
# Epoch: 6, time: 0.9174, Training Loss: 0.0478, Validation Loss: 0.0357
# Epoch: 7, time: 0.8939, Training Loss: 0.0386, Validation Loss: 0.0440
# Epoch: 8, time: 0.8925, Training Loss: 0.0350, Validation Loss: 0.0359
# Epoch: 9, time: 0.8930, Training Loss: 0.0303, Validation Loss: 0.0346
# Epoch: 10, time: 0.8900, Training Loss: 0.0330, Validation Loss: 0.0418
# Epoch: 11, time: 0.8905, Training Loss: 0.0313, Validation Loss: 0.0513
# Epoch: 12, time: 0.9020, Training Loss: 0.0353, Validation Loss: 0.0378
# Epoch: 13, time: 0.8956, Training Loss: 0.0326, Validation Loss: 0.0365
# Epoch: 14, time: 0.8928, Training Loss: 0.0344, Validation Loss: 0.0282
# Epoch: 15, time: 0.8940, Training Loss: 0.0343, Validation Loss: 0.0375
# Epoch: 16, time: 0.8914, Training Loss: 0.0260, Validation Loss: 0.0285
# Epoch: 17, time: 0.8914, Training Loss: 0.0316, Validation Loss: 0.0467
# Epoch: 18, time: 0.9158, Training Loss: 0.0483, Validation Loss: 0.0499
# Epoch: 19, time: 0.9148, Training Loss: 0.0418, Validation Loss: 0.0491
# Epoch: 20, time: 0.9385, Training Loss: 0.0399, Validation Loss: 0.0540
# Epoch: 21, time: 0.9086, Training Loss: 0.0393, Validation Loss: 0.0281
# Epoch: 22, time: 0.8964, Training Loss: 0.0386, Validation Loss: 0.0386
# Epoch: 23, time: 0.8910, Training Loss: 0.0371, Validation Loss: 0.0553
# Epoch: 24, time: 0.8897, Training Loss: 0.0375, Validation Loss: 0.0432
# Epoch: 25, time: 0.8976, Training Loss: 0.0362, Validation Loss: 0.0272
# Epoch: 26, time: 0.8917, Training Loss: 0.0267, Validation Loss: 0.0546
# Epoch: 27, time: 0.8970, Training Loss: 0.0315, Validation Loss: 0.0621
# Epoch: 28, time: 0.9029, Training Loss: 0.0460, Validation Loss: 0.0249
# Epoch: 29, time: 0.8968, Training Loss: 0.0353, Validation Loss: 0.0636
# Epoch: 30, time: 0.8972, Training Loss: 0.0599, Validation Loss: 0.0630
# Epoch: 31, time: 0.8980, Training Loss: 0.0343, Validation Loss: 0.0168
# Epoch: 32, time: 0.9162, Training Loss: 0.0217, Validation Loss: 0.0683
# Epoch: 33, time: 0.9266, Training Loss: 0.0358, Validation Loss: 0.0252
# Epoch: 34, time: 0.9211, Training Loss: 0.0263, Validation Loss: 0.0154
# Epoch: 35, time: 0.9287, Training Loss: 0.0303, Validation Loss: 0.0261
# Epoch: 36, time: 0.9198, Training Loss: 0.0292, Validation Loss: 0.0345
# Epoch: 37, time: 0.9015, Training Loss: 0.0279, Validation Loss: 0.0136
# Epoch: 38, time: 0.8946, Training Loss: 0.0195, Validation Loss: 0.0299
# Epoch: 39, time: 0.8954, Training Loss: 0.0238, Validation Loss: 0.0170
# Epoch: 40, time: 0.9017, Training Loss: 0.0225, Validation Loss: 0.0394
# Training time: 36.499709367752075 seconds

# %%
mm_student_1= student_2_KD(6,6)
mm_student_1.load_state_dict(torch.load('student_2_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:3],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:3],data_gyr[:,:,9:12]),dim=-1)
        output,student_1 = mm_student_1(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_5=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 23.960179855268965
# 16.52368167640195
# 32.69345153545813
#
#
# 0.5795790697579619
# 0.3330558074018147
# 0.5575895689601198
# Mean: 24.392 +/- 8.094
# Mean: 0.490 +/- 0.136

# %% [markdown]
# # Student Model-- 3 IMUs

# %% [markdown]
# ## Training Function

# %%
def train_mm_student_3(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
            data_gyr = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
            output = model(data_acc.to(device).float(), data_gyr.to(device).float())

            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
                data_gyr = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
                output = model(data_acc.to(device).float(), data_gyr.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_3(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_3, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_3(9,9)

mm_student_3 = train_mm_student_3(device, train_loader, val_loader, lr,40,model,'model_student_3.pth')
# Out:
# Epoch: 1, time: 0.5712, Training Loss: 0.7009, Validation Loss: 0.2951
# Epoch: 2, time: 0.5706, Training Loss: 0.1604, Validation Loss: 0.0678
# Epoch: 3, time: 0.5738, Training Loss: 0.0763, Validation Loss: 0.0881
# Epoch: 4, time: 0.5740, Training Loss: 0.0702, Validation Loss: 0.0395
# Epoch: 5, time: 0.5731, Training Loss: 0.0432, Validation Loss: 0.0411
# Epoch: 6, time: 0.5727, Training Loss: 0.0422, Validation Loss: 0.0383
# Epoch: 7, time: 0.5695, Training Loss: 0.0327, Validation Loss: 0.0601
# Epoch: 8, time: 0.5761, Training Loss: 0.0370, Validation Loss: 0.0265
# Epoch: 9, time: 0.5826, Training Loss: 0.0334, Validation Loss: 0.0474
# Epoch: 10, time: 0.5910, Training Loss: 0.0345, Validation Loss: 0.0512
# Epoch: 11, time: 0.5855, Training Loss: 0.0451, Validation Loss: 0.0565
# Epoch: 12, time: 0.5840, Training Loss: 0.0331, Validation Loss: 0.0353
# Epoch: 13, time: 0.5920, Training Loss: 0.0292, Validation Loss: 0.0574
# Epoch: 14, time: 0.5904, Training Loss: 0.0447, Validation Loss: 0.0413
# Epoch: 15, time: 0.6011, Training Loss: 0.0396, Validation Loss: 0.0259
# Epoch: 16, time: 0.5717, Training Loss: 0.0365, Validation Loss: 0.0398
# Epoch: 17, time: 0.5731, Training Loss: 0.0304, Validation Loss: 0.0417
# Epoch: 18, time: 0.5677, Training Loss: 0.0400, Validation Loss: 0.0393
# Epoch: 19, time: 0.5692, Training Loss: 0.0299, Validation Loss: 0.0425
# Epoch: 20, time: 0.5700, Training Loss: 0.0365, Validation Loss: 0.0445
# Epoch: 21, time: 0.5788, Training Loss: 0.0374, Validation Loss: 0.0297
# Epoch: 22, time: 0.5734, Training Loss: 0.0365, Validation Loss: 0.0176
# Epoch: 23, time: 0.5778, Training Loss: 0.0347, Validation Loss: 0.0440
# Epoch: 24, time: 0.5755, Training Loss: 0.0345, Validation Loss: 0.0270
# Epoch: 25, time: 0.5734, Training Loss: 0.0323, Validation Loss: 0.0421
# Epoch: 26, time: 0.5796, Training Loss: 0.0457, Validation Loss: 0.0474
# Epoch: 27, time: 0.5919, Training Loss: 0.0406, Validation Loss: 0.0199
# Epoch: 28, time: 0.5713, Training Loss: 0.0324, Validation Loss: 0.0438
# Epoch: 29, time: 0.5771, Training Loss: 0.0292, Validation Loss: 0.0366
# Epoch: 30, time: 0.5825, Training Loss: 0.0301, Validation Loss: 0.0322
# Epoch: 31, time: 0.5835, Training Loss: 0.0300, Validation Loss: 0.0321
# Epoch: 32, time: 0.5769, Training Loss: 0.0307, Validation Loss: 0.0273
# Stopping early after 32 epochs
# Training time: 18.693551301956177 seconds

# %%
mm_student_3= student_3(9,9)
mm_student_3.load_state_dict(torch.load('model_student_3.pth'))
mm_student_3.to(device)

mm_student_3.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:6],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:6],data_gyr[:,:,9:12]),dim=-1)
        output = mm_student_3(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_6=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 34.96103835369683
# 17.026140485187675
# 33.267125883682326
#
#
# 0.4832733749798885
# 0.33118896829560135
# 0.6195260784620191
# Mean: 28.418 +/- 9.902
# Mean: 0.478 +/- 0.144

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
def train_student_3(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc_1 = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
            data_gyr_1 = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
            student_output, x_student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc_1 = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
                data_gyr_1 = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
                output, student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_3_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_3_KD, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_3_KD(9,9)

teacher_trained= teacher(21,21,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)


student_KD= train_student_3(device, train_loader, val_loader, lr,40, student, 'student_3_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 0.9396, Training Loss: 0.7036, Validation Loss: 0.3030
# Epoch: 2, time: 0.9472, Training Loss: 0.1570, Validation Loss: 0.0397
# Epoch: 3, time: 0.9303, Training Loss: 0.0652, Validation Loss: 0.0393
# Epoch: 4, time: 0.9037, Training Loss: 0.0465, Validation Loss: 0.0864
# Epoch: 5, time: 0.9009, Training Loss: 0.0513, Validation Loss: 0.0390
# Epoch: 6, time: 0.8983, Training Loss: 0.0432, Validation Loss: 0.0339
# Epoch: 7, time: 0.9059, Training Loss: 0.0358, Validation Loss: 0.0439
# Epoch: 8, time: 0.8995, Training Loss: 0.0437, Validation Loss: 0.0472
# Epoch: 9, time: 0.9020, Training Loss: 0.0429, Validation Loss: 0.0339
# Epoch: 10, time: 0.8966, Training Loss: 0.0379, Validation Loss: 0.0419
# Epoch: 11, time: 0.9028, Training Loss: 0.0359, Validation Loss: 0.0350
# Epoch: 12, time: 0.8999, Training Loss: 0.0311, Validation Loss: 0.0458
# Epoch: 13, time: 0.9047, Training Loss: 0.0460, Validation Loss: 0.0302
# Epoch: 14, time: 0.9243, Training Loss: 0.0306, Validation Loss: 0.0356
# Epoch: 15, time: 0.9275, Training Loss: 0.0368, Validation Loss: 0.0243
# Epoch: 16, time: 0.9471, Training Loss: 0.0245, Validation Loss: 0.0213
# Epoch: 17, time: 0.9376, Training Loss: 0.0250, Validation Loss: 0.0747
# Epoch: 18, time: 0.9274, Training Loss: 0.0523, Validation Loss: 0.0681
# Epoch: 19, time: 0.9016, Training Loss: 0.0486, Validation Loss: 0.0319
# Epoch: 20, time: 0.9061, Training Loss: 0.0291, Validation Loss: 0.0885
# Epoch: 21, time: 0.9071, Training Loss: 0.0707, Validation Loss: 0.0721
# Epoch: 22, time: 0.9022, Training Loss: 0.0781, Validation Loss: 0.0989
# Epoch: 23, time: 0.9027, Training Loss: 0.0855, Validation Loss: 0.0161
# Epoch: 24, time: 0.9026, Training Loss: 0.0759, Validation Loss: 0.0772
# Epoch: 25, time: 0.8995, Training Loss: 0.0553, Validation Loss: 0.0387
# Epoch: 26, time: 0.8936, Training Loss: 0.0459, Validation Loss: 0.0620
# Epoch: 27, time: 0.9028, Training Loss: 0.0534, Validation Loss: 0.0623
# Epoch: 28, time: 0.9024, Training Loss: 0.0523, Validation Loss: 0.0282
# Epoch: 29, time: 0.9225, Training Loss: 0.0477, Validation Loss: 0.0314
# Epoch: 30, time: 0.9311, Training Loss: 0.0286, Validation Loss: 0.0220
# Epoch: 31, time: 0.9388, Training Loss: 0.0219, Validation Loss: 0.0427
# Epoch: 32, time: 0.9448, Training Loss: 0.0292, Validation Loss: 0.0304
# Epoch: 33, time: 0.9281, Training Loss: 0.0226, Validation Loss: 0.0228
# Stopping early after 33 epochs
# Training time: 30.51925826072693 seconds

# %%
mm_student_1= student_3_KD(9,9)
mm_student_1.load_state_dict(torch.load('student_3_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:6],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:6],data_gyr[:,:,9:12]),dim=-1)
        output,student_1 = mm_student_1(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_7=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 29.866179657578627
# 16.266137129775263
# 27.286355448750427
#
#
# 0.5177792738893074
# 0.31136930016220554
# 0.5442933840727167
# Mean: 24.473 +/- 7.223
# Mean: 0.458 +/- 0.128

# %% [markdown]
# # Student Model-- 4 IMUs

# %% [markdown]
# ## Training Function

# %%
import torch
import time
import matplotlib.pyplot as plt

def train_mm_student_4(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
            data_gyr = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
            output = model(data_acc.to(device).float(), data_gyr.to(device).float())

            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
                data_gyr = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
                output = model(data_acc.to(device).float(), data_gyr.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_4(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_4, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_4(12,12)

mm_student_4 = train_mm_student_4(device, train_loader, val_loader,  lr,40,model, 'model_student_4.pth')
# Out:
# Epoch: 1, time: 0.5747, Training Loss: 0.7132, Validation Loss: 0.2351
# Epoch: 2, time: 0.5730, Training Loss: 0.1418, Validation Loss: 0.1297
# Epoch: 3, time: 0.5751, Training Loss: 0.0943, Validation Loss: 0.0737
# Epoch: 4, time: 0.5720, Training Loss: 0.0595, Validation Loss: 0.0769
# Epoch: 5, time: 0.5782, Training Loss: 0.0432, Validation Loss: 0.0422
# Epoch: 6, time: 0.5728, Training Loss: 0.0464, Validation Loss: 0.0537
# Epoch: 7, time: 0.5772, Training Loss: 0.0424, Validation Loss: 0.0600
# Epoch: 8, time: 0.5724, Training Loss: 0.0448, Validation Loss: 0.0826
# Epoch: 9, time: 0.5845, Training Loss: 0.0503, Validation Loss: 0.0330
# Epoch: 10, time: 0.5780, Training Loss: 0.0567, Validation Loss: 0.0337
# Epoch: 11, time: 0.5735, Training Loss: 0.0489, Validation Loss: 0.1046
# Epoch: 12, time: 0.5734, Training Loss: 0.0744, Validation Loss: 0.0404
# Epoch: 13, time: 0.5690, Training Loss: 0.0659, Validation Loss: 0.0902
# Epoch: 14, time: 0.5770, Training Loss: 0.0788, Validation Loss: 0.0425
# Epoch: 15, time: 0.5754, Training Loss: 0.0351, Validation Loss: 0.0228
# Epoch: 16, time: 0.5905, Training Loss: 0.0253, Validation Loss: 0.0446
# Epoch: 17, time: 0.5956, Training Loss: 0.0371, Validation Loss: 0.0483
# Epoch: 18, time: 0.5906, Training Loss: 0.0287, Validation Loss: 0.0399
# Epoch: 19, time: 0.5919, Training Loss: 0.0296, Validation Loss: 0.0306
# Epoch: 20, time: 0.5907, Training Loss: 0.0354, Validation Loss: 0.0262
# Epoch: 21, time: 0.5947, Training Loss: 0.0337, Validation Loss: 0.0253
# Epoch: 22, time: 0.5887, Training Loss: 0.0341, Validation Loss: 0.0345
# Epoch: 23, time: 0.5833, Training Loss: 0.0325, Validation Loss: 0.0394
# Epoch: 24, time: 0.5755, Training Loss: 0.0343, Validation Loss: 0.0495
# Epoch: 25, time: 0.5685, Training Loss: 0.0495, Validation Loss: 0.0225
# Epoch: 26, time: 0.5838, Training Loss: 0.0309, Validation Loss: 0.0695
# Epoch: 27, time: 0.5712, Training Loss: 0.0303, Validation Loss: 0.0441
# Epoch: 28, time: 0.5732, Training Loss: 0.0286, Validation Loss: 0.0390
# Epoch: 29, time: 0.5714, Training Loss: 0.0316, Validation Loss: 0.0297
# Epoch: 30, time: 0.5746, Training Loss: 0.0313, Validation Loss: 0.0165
# Epoch: 31, time: 0.5771, Training Loss: 0.0277, Validation Loss: 0.0381
# Epoch: 32, time: 0.5744, Training Loss: 0.0298, Validation Loss: 0.0672
# Epoch: 33, time: 0.5761, Training Loss: 0.0546, Validation Loss: 0.0388
# Epoch: 34, time: 0.5718, Training Loss: 0.0388, Validation Loss: 0.0418
# Epoch: 35, time: 0.5765, Training Loss: 0.0273, Validation Loss: 0.0242
# Epoch: 36, time: 0.5698, Training Loss: 0.0248, Validation Loss: 0.0160
# Epoch: 37, time: 0.5714, Training Loss: 0.0195, Validation Loss: 0.0411
# Epoch: 38, time: 0.5739, Training Loss: 0.0281, Validation Loss: 0.0273
# Epoch: 39, time: 0.5810, Training Loss: 0.0289, Validation Loss: 0.0261
# Epoch: 40, time: 0.5769, Training Loss: 0.0285, Validation Loss: 0.0328
# Training time: 23.36299419403076 seconds

# %%
mm_student_4= student_4(12,12)
mm_student_4.load_state_dict(torch.load('model_student_4.pth'))
mm_student_4.to(device)

mm_student_4.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:9],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:9],data_gyr[:,:,9:12]),dim=-1)
        output = mm_student_4(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_8=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 27.845061461994913
# 14.707167891089624
# 24.71538774817269
#
#
# 0.473316910229333
# 0.39889166064843884
# 0.627845832729163
# Mean: 22.423 +/- 6.863
# Mean: 0.500 +/- 0.117

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
def train_student_4(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc_1 = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
            data_gyr_1 = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
            student_output, x_student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc_1 = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
                data_gyr_1 = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
                output, student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_4_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_4_KD, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_4_KD(12,12)

teacher_trained= teacher(21,21,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)


student_KD= train_student_4(device, train_loader, val_loader, lr,40, student,'student_4_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 0.9410, Training Loss: 0.7250, Validation Loss: 0.3194
# Epoch: 2, time: 0.9544, Training Loss: 0.1763, Validation Loss: 0.1029
# Epoch: 3, time: 0.9452, Training Loss: 0.0933, Validation Loss: 0.0663
# Epoch: 4, time: 0.8972, Training Loss: 0.0637, Validation Loss: 0.0985
# Epoch: 5, time: 0.9052, Training Loss: 0.0822, Validation Loss: 0.0673
# Epoch: 6, time: 0.9025, Training Loss: 0.0541, Validation Loss: 0.0335
# Epoch: 7, time: 0.9035, Training Loss: 0.0431, Validation Loss: 0.0424
# Epoch: 8, time: 0.9025, Training Loss: 0.0408, Validation Loss: 0.0667
# Epoch: 9, time: 0.9019, Training Loss: 0.0454, Validation Loss: 0.0602
# Epoch: 10, time: 0.9048, Training Loss: 0.0384, Validation Loss: 0.0299
# Epoch: 11, time: 0.9036, Training Loss: 0.0356, Validation Loss: 0.0295
# Epoch: 12, time: 0.9049, Training Loss: 0.0335, Validation Loss: 0.0215
# Epoch: 13, time: 0.9042, Training Loss: 0.0312, Validation Loss: 0.0515
# Epoch: 14, time: 0.9097, Training Loss: 0.0357, Validation Loss: 0.0354
# Epoch: 15, time: 0.9273, Training Loss: 0.0287, Validation Loss: 0.0372
# Epoch: 16, time: 0.9311, Training Loss: 0.0268, Validation Loss: 0.0474
# Epoch: 17, time: 0.9404, Training Loss: 0.0329, Validation Loss: 0.0245
# Epoch: 18, time: 0.9325, Training Loss: 0.0296, Validation Loss: 0.0598
# Epoch: 19, time: 0.9093, Training Loss: 0.0454, Validation Loss: 0.0553
# Epoch: 20, time: 0.9079, Training Loss: 0.0428, Validation Loss: 0.0346
# Epoch: 21, time: 0.9056, Training Loss: 0.0412, Validation Loss: 0.0294
# Epoch: 22, time: 0.9019, Training Loss: 0.0415, Validation Loss: 0.0288
# Stopping early after 22 epochs
# Training time: 20.391501665115356 seconds

# %%
mm_student_1= student_4_KD(12,12)
mm_student_1.load_state_dict(torch.load('student_4_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:9],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:9],data_gyr[:,:,9:12]),dim=-1)
        output,student_1 = mm_student_1(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_9=np.hstack([rmse,p])
# Out:
# (976, 100, 3)
# 27.44432681985763
# 16.528266786339895
# 34.605998819548866
#
#
# 0.3169932239813735
# 0.4035854494951174
# 0.5113207545220922
# Mean: 26.193 +/- 9.104
# Mean: 0.411 +/- 0.097
