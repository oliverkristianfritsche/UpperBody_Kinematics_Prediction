# %%
#!pip install torchviz
# !pip install tsf


import json
import matplotlib.pyplot as plt
import numpy as np
import numpy
import statistics
from numpy import loadtxt
import matplotlib.pyplot as plt
import pandas
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from statistics import stdev
import math
# import h5py

import numpy as np
import time

from scipy.signal import butter,filtfilt
import sys
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph
import seaborn as sns # used for plot interactive graph.
import pandas
import matplotlib.pyplot as plt

# from tsf.model import TransformerForecaster


# from tensorflow.keras.utils import np_utils
import itertools
###  Library for attention layers
import pandas as pd
import os
import numpy as np
#from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split

import statistics
import gc
import torch.nn.init as init

############################################################################################################################################################################
############################################################################################################################################################################

import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.nn.utils.weight_norm as weight_norm
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Dataset
import torch.nn.functional as F
#from torchsummary import summary
from torch.nn.parameter import Parameter

#from torchsummary import summary



import torch.optim as optim
import gc

from tqdm.notebook import tqdm
from sklearn.preprocessing import MinMaxScaler, StandardScaler


from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/sd_datacollection"

# %%
#to delete data produced by datasharding function
import shutil
import os

yes_delete = False

if yes_delete:
    # Example path to the folder you want to delete
    folder_path = '/content/datasets'
    # Delete the folder and its contents recursively
    shutil.rmtree(folder_path)

# %% [markdown]
# # File path

# %% [markdown]
# # Data loader

# %%
# Index 0: pelvis_tilt
# Index 1: pelvis_list
# Index 2: pelvis_rotation
# Index 3: pelvis_tx
# Index 4: pelvis_ty
# Index 5: pelvis_tz
# Index 6: hip_flexion_r
# Index 7: hip_adduction_r
# Index 8: hip_rotation_r
# Index 9: knee_angle_r
# Index 10: knee_angle_r_beta
# Index 11: ankle_angle_r
# Index 12: subtalar_angle_r
# Index 13: mtp_angle_r
# Index 14: hip_flexion_l
# Index 15: hip_adduction_l
# Index 16: hip_rotation_l
# Index 17: knee_angle_l
# Index 18: knee_angle_l_beta
# Index 19: ankle_angle_l
# Index 20: subtalar_angle_l
# Index 21: mtp_angle_l
# Index 22: lumbar_extension
# Index 23: lumbar_bending
# Index 24: lumbar_rotation
# Index 25: arm_flex_r
# Index 26: arm_add_r
# Index 27: arm_rot_r
# Index 28: elbow_flex_r
# Index 29: pro_sup_r
# Index 30: wrist_flex_r
# Index 31: wrist_dev_r
# Index 32: arm_flex_l
# Index 33: arm_add_l
# Index 34: arm_rot_l
# Index 35: elbow_flex_l
# Index 36: pro_sup_l
# Index 37: wrist_flex_l
# Index 38: wrist_dev_l
# Index 39: time
# Index 40: 1
# Index 41: IM EMG1
# Index 42: IM EMG2
# Index 43: IM EMG3
# Index 44: IM EMG4
# Index 45: IM EMG5
# Index 46: IM EMG6
# Index 47: IM EMG7
# Index 48: IM EMG8
# Index 49: ACCX1
# Index 50: ACCY1
# Index 51: ACCZ1
# Index 52: GYROX1
# Index 53: GYROY1
# Index 54: GYROZ1
# Index 55: ACCX2
# Index 56: ACCY2
# Index 57: ACCZ2
# Index 58: GYROX2
# Index 59: GYROY2
# Index 60: GYROZ2
# Index 61: ACCX3
# Index 62: ACCY3
# Index 63: ACCZ3
# Index 64: GYROX3
# Index 65: GYROY3
# Index 66: GYROZ3
# Index 67: ACCX4
# Index 68: ACCY4
# Index 69: ACCZ4
# Index 70: GYROX4
# Index 71: GYROY4
# Index 72: GYROZ4
# Index 73: ACCX5
# Index 74: ACCY5
# Index 75: ACCZ5
# Index 76: GYROX5
# Index 77: GYROY5
# Index 78: GYROZ5
# Index 79: ACCX6
# Index 80: ACCY6
# Index 81: ACCZ6
# Index 82: GYROX6
# Index 83: GYROY6
# Index 84: GYROZ6
# Index 85: ACCX7
# Index 86: ACCY7
# Index 87: ACCZ7
# Index 88: GYROX7
# Index 89: GYROY7
# Index 90: GYROZ7
# Index 91: ACCX8
# Index 92: ACCY8
# Index 93: ACCZ8
# Index 94: GYROX8
# Index 95: GYROY8
# Index 96: GYROZ8

columns_imu_acc = ['ACCX1', 'ACCY1', 'ACCZ1','ACCX2', 'ACCY2', 'ACCZ2','ACCX3', 'ACCY3', 'ACCZ3','ACCX4', 'ACCY4', 'ACCZ4','ACCX5', 'ACCY5', 'ACCZ5', 'ACCX6', 'ACCY6', 'ACCZ6']

#made due to difference in subject 1 and subject 2 data
columns_imu_acc_test = ['ACCX1', 'ACCY1', 'ACCZ1','ACCX2', 'ACCY2', 'ACCZ2','ACCX3', 'ACCY3', 'ACCZ3','ACCX4', 'ACCY4', 'ACCZ4','ACCX5', 'ACCY5', 'ACCZ5', 'ACCX6', 'ACCY6', 'ACCZ6']

columns_imu_gyr = ['GYROX1', 'GYROY1', 'GYROZ1','GYROX2', 'GYROY2', 'GYROZ2','GYROX3', 'GYROY3', 'GYROZ3','GYROX4', 'GYROY4', 'GYROZ4','GYROX5', 'GYROY5', 'GYROZ5', 'GYROX6', 'GYROY6', 'GYROZ6']

#made due to difference in subject 1 and subject 2 data
columns_imu_gyr_test = ['GYROX1', 'GYROY1', 'GYROZ1','GYROX2', 'GYROY2', 'GYROZ2', 'GYROX3', 'GYROY3', 'GYROZ3','GYROX4', 'GYROY4', 'GYROZ4','GYROX5', 'GYROY5', 'GYROZ5', 'GYROX6', 'GYROY6', 'GYROZ6']

columns_joints = ['elbow_flex_r','arm_flex_r','arm_add_r']

# %%
#CONFIG

class config_general:
    #device = 'cuda' if torch.cuda.is_available() else 'cpu'

    def __init__(self, **kwargs):
        self.batch_size = kwargs.get('batch_size', 16)
        self.epochs = kwargs.get('epochs', 10)
        self.lr = kwargs.get('lr', 0.001)
        self.scheduler = kwargs.get('scheduler', None)
        self.channels_imu_acc = kwargs.get('channels_imu_acc', None)
        self.channels_imu_acc_test = kwargs.get('channels_imu_acc_test', None)
        self.channels_imu_gyr_test = kwargs.get('channels_imu_gyr_test', None)
        self.channels_imu_gyr = kwargs.get('channels_imu_gyr', None)
        self.channels_joints = kwargs.get('channels_joints', None)
        self.channels_emg = kwargs.get('channels_emg', None)
        self.num_sessions = kwargs.get('num_sessions', None)
        self.num_patients = kwargs.get('num_patients', None)
        self.seed = kwargs.get('seed', 42)
        self.data_folder_name = kwargs.get('data_folder_name', 'default_data_folder_name')
        self.dataset_root = kwargs.get('dataset_root', 'default_dataset_root')
        self.dataset_train_name = kwargs.get('dataset_train_name', 'train')
        self.dataset_test_name = kwargs.get('dataset_test_name', 'test')
        self.dataset_name = kwargs.get('dataset_name', 'default_dataset_name')
        self.window_length = kwargs.get('window_length', 100)
        self.window_overlap = kwargs.get('window_overlap', 0)
        self.imu_transforms = kwargs.get('imu_transforms', [])
        self.joint_transforms = kwargs.get('joint_transforms', [])
        self.emg_transforms = kwargs.get('emg_transforms', [])
        self.hidden_size = kwargs.get('hidden_size', 256)
        self.num_layers = kwargs.get('num_layers', 6)
        self.input_size = kwargs.get('input_size', 3)
        self.output_size = kwargs.get('output_size', 3)
        self.sample_rate =kwargs.get('sample_rate', 100)
        self.input_format =  kwargs.get('input_format', 'vicon') # csv or wav

        hyperparameters = [
            f"batch_size_{self.batch_size}",
            f"epochs_{self.epochs}",
            f"lr_{self.lr}",
            f"scheduler_{self.scheduler}",
            f"channels_imu_gyr_{self.channels_imu_gyr}",
            f"channels_imu_acctest__{self.channels_imu_acc_test}",
            f"channels_imu_acc_{self.channels_imu_acc}",
            f"channels_imu_gyr_test_{self.channels_imu_gyr_test}",
            f"channels_joints_{self.channels_joints}",
            f"channels_emg_{self.channels_emg}",
            f"num_sessions_{self.num_sessions}",
            f"num_patients_{self.num_patients}",
            f"seed_{self.seed}",
            f"data_folder_name_{self.data_folder_name}",
            f"dataset_root_{self.dataset_root}",
            f"dataset_train_name_{self.dataset_train_name}",
            f"dataset_test_name_{self.dataset_test_name}",
            f"window_length_{self.window_length}",
            f"imu_transforms_{self.imu_transforms}",
            f"joint_transforms_{self.joint_transforms}",
            f"emg_transforms_{self.emg_transforms}",
            f"hidden_size_{self.hidden_size}",
            f"num_layers_{self.num_layers}",
            f"input_size_{self.input_size}",
            f"output_size_{self.output_size}",
            f"sample_rate_{self.sample_rate}",
            f"input_format_{self.input_format}"
        ]

        self.hyperparameters_str = "_".join(map(str, hyperparameters))

# %%
#FUNCTION TO RETRIEVE DATA FROM WAV FILES
from scipy.io import wavfile

def get_data_from_wav_file(filename): #return data shape [time_steps,channels]
        sample_rate, data = wavfile.read(filename)
        # print(f"Sample rate: {sample_rate}Hz|Data shape: {data.shape}")
        return data, sample_rate

# %%
#USE CONFIG
from scipy.signal import savgol_filter

# Smoothing function
def smooth_joint_data(joint_data, window_length=11, polyorder=2):
    """
    Smooth the joint data using a Savitzky-Golay filter.
    :param joint_data: numpy array, input joint data to be smoothed
    :param window_length: int, length of the filter window (must be odd)
    :param polyorder: int, order of the polynomial used to fit the samples
    :return: numpy array, smoothed joint data
    """
    return savgol_filter(joint_data, window_length=window_length, polyorder=polyorder, axis=0)

config = config_general(
    data_folder_name=file_path,
    dataset_root="datasets",
    dataset_name="two_subject_downsampled",
    window_length=100,
    window_overlap=50,
    input_format="csv",
    num_patients=10,
    channels_imu_acc= columns_imu_acc,  # Column name for accelerometer data in CSV
    channels_imu_acc_test=columns_imu_acc_test,  # Column name for accelerometer data in CSV
    channels_imu_gyr_test=columns_imu_gyr_test,  # Column name for gyroscope data in CSV
    channels_imu_gyr=columns_imu_gyr,  # Column name for gyroscope data in CSV
    channels_joints=columns_joints,  # Column name for joint data in CSV
    channels_emg=['IM EMG4', 'IM EMG5', 'IM EMG6'],
    imu_transforms=[],
    joint_transforms=[],
    emg_transforms=[]
)

# %%
class DataSharder:
    def __init__(self, config, save_h5=False):
        self.config = config
        self.sample_rate = config.sample_rate
        self.input_format = config.input_format
        self.data_folder_path = config.data_folder_name
        self.window_length = int(config.window_length)
        self.window_overlap = int(config.window_overlap)
        self.num_patients = int(config.num_patients)
        self.save_h5 = save_h5

    def load_data(self):
        patient_folders_list = [f for f in os.listdir(self.data_folder_path) if os.path.isdir(os.path.join(self.data_folder_path, f))]
        patient_folders_list.sort(key=lambda x: int(x.split('_')[-1]))
        patient_folders_list = [f for f in patient_folders_list if os.path.isdir(os.path.join(self.data_folder_path, f, "combined"))]

        print("Patient List", patient_folders_list)

        training_patients = patient_folders_list[:-1]
        testing_patients = [patient_folders_list[-1]]
        print(f"Training patients: {training_patients}")
        print(f"Testing patients: {testing_patients}")

        if self.input_format == 'wav':
            self._process_and_save_patients_wav(training_patients, "train")
            self._process_and_save_patients_wav(testing_patients, "test")
        elif self.input_format == 'csv':
            self._process_and_save_patients_csv(training_patients, "train")
            self._process_and_save_patients_csv(testing_patients, "test")
        else:
            raise ValueError(f"Unsupported input format: {self.input_format}")

    def _process_and_save_patients_wav(self, patient_id_list, split):
        total_data = []
        for patient_id in tqdm(patient_id_list, desc=f"Processing {split} patients"):
            for session_index in tqdm(range(self.config.num_sessions), desc=f"Processing sessions for {patient_id}", leave=False):
                imu_data, imu_sample_rate = self._load_wav_file(patient_id, session_index, "IMU")
                joints_data, joints_sample_rate = self._load_wav_file(patient_id, session_index, "JOINTS")
                emg_data, emg_sample_rate = self._load_wav_file(patient_id, session_index, "EMG")

                imu_data = self._resample_data(imu_data, imu_sample_rate)
                joints_data = self._resample_data(joints_data, joints_sample_rate)
                emg_data = self._resample_data(emg_data, emg_sample_rate)

                combined_data = torch.cat((imu_data, joints_data, emg_data), dim=1)
                total_data.append(combined_data.cpu().numpy())

        if self.save_h5:
            self._save_to_h5(total_data, split)
        else:
            for combined_data in total_data:
                self._save_windowed_data(combined_data, patient_id, session_index, split)

    def _load_wav_file(self, patient_id, session_index, file_type):
        file_path = os.path.join(self.data_folder_path, patient_id, f"run{session_index}_{file_type}.wav")
        data, sample_rate = get_data_from_wav_file(file_path)
        return torch.tensor(data, dtype=torch.float32), sample_rate

    def _resample_data(self, data, sample_rate):
        if sample_rate != self.sample_rate:
            data = T.Resample(sample_rate, self.sample_rate)(data.T).T
        return data

    def _process_and_save_patients_csv(self, patient_id_list, split):
      column_names = None
      for patient_id in tqdm(patient_id_list, desc=f"Processing {split} patients"):
          combined_path = os.path.join(self.data_folder_path, patient_id, "combined")
          if not os.path.exists(combined_path):
              print(f"Directory {combined_path} does not exist. Skipping patient {patient_id}.")
              continue

          patient_files = os.listdir(combined_path)
          for session_file in tqdm(patient_files, desc=f"Processing sessions for {patient_id}", leave=False):
              data = pd.read_csv(os.path.join(combined_path, session_file))
              if column_names is None:
                  column_names = data.columns
              data_np = data.to_numpy()
              # Pad array to fit columns if necessary
              if data_np.shape[1] < len(column_names):
                  data_np = np.pad(data_np, ((0, 0), (0, len(column_names) - data_np.shape[1])), mode='constant')

              self._save_windowed_data(pd.DataFrame(data_np, columns=column_names), patient_id, session_file.split('.')[0], split, is_csv=True)


    def _save_windowed_data(self, data, patient_id, session_id, split, is_csv=False):
        dataset_name = f"{self.config.dataset_name}_wl{self.window_length}_ol{self.window_overlap}_np{self.num_patients}"
        dataset_folder = os.path.join(self.config.dataset_root, dataset_name, self.config.dataset_train_name if split == "train" else self.config.dataset_test_name)
        os.makedirs(dataset_folder, exist_ok=True)

        window_size = self.window_length
        overlap = self.window_overlap
        step_size = window_size - overlap

        data_info_list = []

        for i in tqdm(range(0, len(data) - window_size + 1, step_size), desc=f"Windowing data for {patient_id}_{session_id}", leave=False):
            windowed_data = data.iloc[i:i+window_size] if is_csv else data[i:i+window_size]
            if windowed_data.shape[0] < window_size:
                continue

            windowed_data_np = windowed_data.to_numpy() if is_csv else windowed_data.cpu().numpy()

            file_name = f"{patient_id}_session_{session_id}_window_{i}_ws{window_size}_ol{overlap}.csv"
            file_path = os.path.join(dataset_folder, file_name)
            pd.DataFrame(windowed_data_np, columns=data.columns if is_csv else None).to_csv(file_path, index=False)
            data_info_list.append({"file_name": file_name, "file_path": file_path})

        data_info_df = pd.DataFrame(data_info_list)
        data_info_df.to_csv(os.path.join(self.config.dataset_root, dataset_name, f"{split}_info.csv"), index=False, mode='a', header=not os.path.exists(os.path.join(self.config.dataset_root, dataset_name, f"{split}_info.csv")))

    def _save_to_h5(self, data_list, split, column_names=None):
        dataset_name = f"{self.config.dataset_name}_np{self.num_patients}"
        h5_file_path = os.path.join(self.config.dataset_root, dataset_name, f"{split}_data.h5")

        combined_data = np.array(data_list)
        print(combined_data.shape)

        os.makedirs(os.path.dirname(h5_file_path), exist_ok=True)

        with h5py.File(h5_file_path, 'w') as h5file:
            h5file.create_dataset(f"{split}_data", data=combined_data)
            if column_names is not None:
                h5file.create_dataset(f"{split}_columns", data=np.array(column_names, dtype='S'))

# %%
#USE DATASHARDER
# !pwd
import torch
import h5py
reshard_data = True
if reshard_data:
    data_sharder = DataSharder(config)
    data_sharder.load_data()
# Out:
# /content
# Patient List ['subject_1', 'subject_2', 'subject_3', 'subject_6', 'subject_7', 'subject_9', 'subject_10']
# Training patients: ['subject_1', 'subject_2', 'subject_3', 'subject_6', 'subject_7', 'subject_9']
# Testing patients: ['subject_10']
# Processing train patients:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing sessions for subject_1:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_crossbody_fast_combined:   0%|          | 0/65 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_elbowrotation_fast_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_overheadreach_max_combined:   0%|          | 0/65 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_elbowrotation_normal_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_overheadreach_45_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_elbowflexion_normal_combined:   0%|          | 0/64 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_crossbody_slow_combined:   0%|          | 0/65 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_elbowflexion_fast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_armSwing_fast_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_elbowrotation_slow_combined:   0%|          | 0/66 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_armSwing_veryfast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_armSwing_normal_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_crossbody_normal_combined:   0%|          | 0/66 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_overheadreach_90_combined:   0%|          | 0/65 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_elbowflexion_slow_combined:   0%|          | 0/64 [00:00<?, ?it/s]
# Windowing data for subject_1_P001_T001_armSwing_slow_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Processing sessions for subject_2:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_armSwing_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_overheadreach_90_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_overheadreach_max_combined:   0%|          | 0/59 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_elboxflexion_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_elboxflexion_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_elboxflexion_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_crossbody_slow_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_overheadreach_45_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_armSwing_slow_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_crossbody_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_elbowrotation_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_elbowrotation_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_armSwing_veryfast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_elbowrotation_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_crossbody_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_2_P002_T001_armSwing_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Processing sessions for subject_3:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_armswing_normal_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_armswing_fast_combined:   0%|          | 0/65 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T003_armswing_slow_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_armswing_veryfast_combined:   0%|          | 0/64 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_overheadreach45_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_overheadreach90_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_elbowrotation_fast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_elbowflexion_slow_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_elbowflexion_fast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_overheadreachMax_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_elbowrotation_normal_combined:   0%|          | 0/39 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_elbowflexion_normal_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_crossbody_fast_combined:   0%|          | 0/64 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_crossbody_slow_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T001_crossbody_normal_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_3_P003_T002_elbowrotation_slow_combined:   0%|          | 0/65 [00:00<?, ?it/s]
# Processing sessions for subject_6:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_armSwing_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_armSwing_veryfast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_armSwing_slow_combined:   0%|          | 0/56 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_armSwing_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_overheadreach_max_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_overheadreach_90_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_elbowflexion_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_elbowflexion_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_elbowflexion_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_elbowrotation_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_elbowrotation_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T001_elbowrotation_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T002_crossbody_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T002_crossbody_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T002_crossbody_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_6_P006_T002_overheadreach_45_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Processing sessions for subject_7:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T002_armSwing_slow_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_armSwing_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_armSwing_veryfast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_elbowflexion_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_overheadreach_90_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_overheadreach_45_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_armSwing_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_elbowrotation_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_overheadreach_max_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_elbowflexion_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_elbowflexion_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_crossbody_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_elbowrotation_normal_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_crossbody_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_elbowrotation_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_7_P007_T001_crossbody_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Processing sessions for subject_9:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_armswing_slow_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_armswing_fast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_overheadreach_45_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_elbowflexion_normal_combined:   0%|          | 0/64 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_elbowflexion_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_elbowrotation_slow_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_elbowrotation_normal_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_crossbody_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_armswing_veryfast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_armswing_normal_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_elbowrotation_fast_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_crossbody_fast_combined:   0%|          | 0/62 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_overheadreach_max_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_overheadreach_90_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T001_elbowflexion_slow_combined:   0%|          | 0/63 [00:00<?, ?it/s]
# Windowing data for subject_9_P009_T002_crossbody_normal_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Processing test patients:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing sessions for subject_10:   0%|          | 0/16 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T002_elbowrotation_normal_combined:   0%|          | 0/61 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T002_elbowrotation_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_armSwing_veryfast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_overheadreach_45_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_armSwing_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_armSwing_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_elbowflexion_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_crossbody_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_elbowflexion_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T002_elbowrotation_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_overheadreach_90_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_elbowflexion_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_armSwing_normal_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_crossbody_fast_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_crossbody_slow_combined:   0%|          | 0/60 [00:00<?, ?it/s]
# Windowing data for subject_10_P010_T001_overheadreach_max_combined:   0%|          | 0/61 [00:00<?, ?it/s]

# %% [markdown]
# # Data processing

# %%
#DATASET OBJECT
from torchvision.transforms import ToTensor
import joblib


class ImuJointPairDataset(Dataset):
    def __init__(self, config, split='train'):
        self.config = config
        self.split = split
        self.input_format = config.input_format
        self.channels_imu_acc = config.channels_imu_acc
        self.channels_imu_acc_test = config.channels_imu_acc_test
        self.channels_imu_gyr = config.channels_imu_gyr
        self.channels_imu_gyr_test = config.channels_imu_gyr_test
        self.channels_joints = config.channels_joints
        self.channels_emg = config.channels_emg

        dataset_name = f"{self.config.dataset_name}_wl{self.config.window_length}_ol{self.config.window_overlap}_np{self.config.num_patients}"
        self.root_dir_train = os.path.join(self.config.dataset_root, dataset_name, self.config.dataset_train_name)
        self.root_dir_test = os.path.join(self.config.dataset_root, dataset_name, self.config.dataset_test_name)

        train_info_path = os.path.join(self.config.dataset_root, dataset_name, "train_info.csv")
        test_info_path = os.path.join(self.config.dataset_root, dataset_name, "test_info.csv")
        self.data = pd.read_csv(train_info_path) if split == 'train' else pd.read_csv(test_info_path)

        self.scaler_save_path = os.path.join(self.config.dataset_root, dataset_name, "scaler.pkl")

    def _fit_scaler(self, train_info_path):
        all_data = []
        train_info = pd.read_csv(train_info_path)
        if self.split == "train":
            for idx in range(len(train_info)):
                file_path = os.path.join(self.root_dir_train, train_info.iloc[idx, 0])
                if self.input_format == "csv":
                    combined_data = pd.read_csv(file_path)
                    imu_data_acc = combined_data[self.channels_imu_acc].values
                    imu_data_gyr = combined_data[self.channels_imu_gyr].values
                    joint_data = combined_data[self.channels_joints].values
                    emg_data = combined_data[self.channels_emg].values
                    all_data.append(np.concatenate([imu_data_acc, imu_data_gyr, joint_data, emg_data], axis=1))

        else:
            for idx in range(len(train_info)):
                file_path = os.path.join(self.root_dir_test, train_info.iloc[idx, 0])
                if self.input_format == "csv":
                    combined_data = pd.read_csv(file_path)
                    imu_data_acc = combined_data[self.channels_imu_acc_test].values
                    imu_data_gyr = combined_data[self.channels_imu_gyr_test].values
                    joint_data = combined_data[self.channels_joints].values
                    emg_data = combined_data[self.channels_emg].values
                    all_data.append(np.concatenate([imu_data_acc, imu_data_gyr, joint_data, emg_data], axis=1))

        all_data = np.vstack(all_data)
        self.scaler.fit(all_data)

        os.makedirs(os.path.dirname(self.scaler_save_path), exist_ok=True)
        joblib.dump(self.scaler, self.scaler_save_path)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if self.split == "train":
            file_path = os.path.join(self.root_dir_train, self.data.iloc[idx, 0])
        else:
            file_path = os.path.join(self.root_dir_test, self.data.iloc[idx, 0])

        if self.input_format == "wav":
            combined_data, _ = get_data_from_wav_file(file_path)
        elif self.input_format == "csv":
            combined_data = pd.read_csv(file_path)
        else:
            raise ValueError("Unsupported input format: {}".format(self.input_format))

        if self.split == 'train':
            if isinstance(self.channels_imu_acc, slice):
                imu_data_acc = combined_data.iloc[:, self.channels_imu_acc].values if self.input_format == "csv" else combined_data[:, self.channels_imu_acc]
            else:
                imu_data_acc = combined_data[self.channels_imu_acc].values if self.input_format == "csv" else combined_data[:, self.channels_imu_acc]

            if isinstance(self.channels_imu_gyr, slice):
                imu_data_gyr = combined_data.iloc[:, self.channels_imu_gyr].values if self.input_format == "csv" else combined_data[:, self.channels_imu_gyr]
            else:
                imu_data_gyr = combined_data[self.channels_imu_gyr].values if self.input_format == "csv" else combined_data[:, self.channels_imu_gyr]

            if isinstance(self.channels_joints, slice):
                joint_data = combined_data.iloc[:, self.channels_joints].values if self.input_format == "csv" else combined_data[:, self.channels_joints]
            else:
                joint_data = combined_data[self.channels_joints].values if self.input_format == "csv" else combined_data[:, self.channels_joints]

            if isinstance(self.channels_emg, slice):
                emg_data = combined_data.iloc[:, self.channels_emg].values if self.input_format == "csv" else combined_data[:, self.channels_emg]
            else:
                emg_data = combined_data[self.channels_emg].values if self.input_format == "csv" else combined_data[:, self.channels_emg]

            combined_data = np.concatenate([imu_data_acc, imu_data_gyr, joint_data, emg_data], axis=1)
            scaled_data = combined_data

            imu_data_acc = scaled_data[:, :imu_data_acc.shape[1]]
            imu_data_gyr = scaled_data[:, imu_data_acc.shape[1]:imu_data_acc.shape[1] + imu_data_gyr.shape[1]]
            joint_data = scaled_data[:, imu_data_acc.shape[1] + imu_data_gyr.shape[1]:imu_data_acc.shape[1] + imu_data_gyr.shape[1] + joint_data.shape[1]]
            emg_data = scaled_data[:, imu_data_acc.shape[1] + imu_data_gyr.shape[1] + joint_data.shape[1]:]

            imu_data_acc = self.apply_transforms(imu_data_acc, self.config.imu_transforms)
            imu_data_gyr = self.apply_transforms(imu_data_gyr, self.config.imu_transforms)
            joint_data = self.apply_transforms(joint_data, self.config.joint_transforms)
            emg_data = self.apply_transforms(emg_data, self.config.emg_transforms)

            return imu_data_acc, imu_data_gyr, joint_data, emg_data

        else:
            if isinstance(self.channels_imu_acc_test, slice):
                imu_data_acc = combined_data.iloc[:, self.channels_imu_acc_test].values if self.input_format == "csv" else combined_data[:, self.channels_imu_acc_test]
            else:
                imu_data_acc = combined_data[self.channels_imu_acc_test].values if self.input_format == "csv" else combined_data[:, self.channels_imu_acc_test]

            if isinstance(self.channels_imu_gyr_test, slice):
                imu_data_gyr = combined_data.iloc[:, self.channels_imu_gyr_test].values if self.input_format == "csv" else combined_data[:, self.channels_imu_gyr_test]
            else:
                imu_data_gyr = combined_data[self.channels_imu_gyr_test].values if self.input_format == "csv" else combined_data[:, self.channels_imu_gyr_test]

            if isinstance(self.channels_joints, slice):
                joint_data = combined_data.iloc[:, self.channels_joints].values if self.input_format == "csv" else combined_data[:, self.channels_joints]
            else:
                joint_data = combined_data[self.channels_joints].values if self.input_format == "csv" else combined_data[:, self.channels_joints]

            if isinstance(self.channels_emg, slice):
                emg_data = combined_data.iloc[:, self.channels_emg].values if self.input_format == "csv" else combined_data[:, self.channels_emg]
            else:
                emg_data = combined_data[self.channels_emg].values if self.input_format == "csv" else combined_data[:, self.channels_emg]

            combined_data = np.concatenate([imu_data_acc, imu_data_gyr, joint_data, emg_data], axis=1)
            scaled_data = combined_data

            imu_data_acc = scaled_data[:, :imu_data_acc.shape[1]]
            imu_data_gyr = scaled_data[:, imu_data_acc.shape[1]:imu_data_acc.shape[1] + imu_data_gyr.shape[1]]
            joint_data = scaled_data[:, imu_data_acc.shape[1] + imu_data_gyr.shape[1]:imu_data_acc.shape[1] + imu_data_gyr.shape[1] + joint_data.shape[1]]
            emg_data = scaled_data[:, imu_data_acc.shape[1] + imu_data_gyr.shape[1] + joint_data.shape[1]:]

            imu_data_acc = self.apply_transforms(imu_data_acc, self.config.imu_transforms)
            imu_data_gyr = self.apply_transforms(imu_data_gyr, self.config.imu_transforms)
            joint_data = self.apply_transforms(joint_data, self.config.joint_transforms)
            emg_data = self.apply_transforms(emg_data, self.config.emg_transforms)

            return imu_data_acc, imu_data_gyr, joint_data, emg_data

    def apply_transforms(self, data, transforms):
      for transform in transforms:
          data = transform(data)

      data = ToTensor()(data).squeeze(0)
      return data

# %%
import joblib

from torchvision.transforms import ToTensor

#create datasets
train_dataset = ImuJointPairDataset(config, split='train')
print(train_dataset.__getitem__(0)[0].shape, train_dataset.__getitem__(0)[1].shape, train_dataset.__getitem__(0)[2].shape, train_dataset.__getitem__(0)[3].shape)
test_dataset = ImuJointPairDataset(config, split='test')
print(test_dataset.__getitem__(0)[0].shape, test_dataset.__getitem__(0)[1].shape, test_dataset.__getitem__(0)[2].shape, test_dataset.__getitem__(0)[3].shape)
# Out:
# torch.Size([100, 18]) torch.Size([100, 18]) torch.Size([100, 3]) torch.Size([100, 3])
# torch.Size([100, 18]) torch.Size([100, 18]) torch.Size([100, 3]) torch.Size([100, 3])

# %%
#setup validation dataset
train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.1, random_state=42)

# %%
#setup dataloaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Get the first batch from the train loader
data_acc, data_gyr, data_targets, data_emg = next(iter(train_loader))

print(f"Data shape: {data_acc.shape}, {data_gyr.shape}, {data_targets.shape}, {data_emg.shape}")

# Plot the first element in the train loader
#plot_data_kinelight(x, y, config, test_dataset.scaler, "Train")

# Optionally, plot the first element in the test loader
#x_test, y_test = next(iter(test_loader))
#plot_data_kinelight(x_test, y_test, config, test_dataset.scaler, "Test")
# Out:
# Data shape: torch.Size([64, 100, 18]), torch.Size([64, 100, 18]), torch.Size([64, 100, 3]), torch.Size([64, 100, 3])

# %%
plt.plot(data_acc[0])
plt.show()

plt.plot(data_gyr[0])
plt.show()

plt.plot(data_targets[0])
plt.show()

plt.plot(data_emg[0])
plt.show()

# %% [markdown]
# # Important Functions

# %%
#prediction function
def RMSE_prediction(yhat_4,test_y, output_dim):

  s1=yhat_4.shape[0]*yhat_4.shape[1]

  test_o=test_y.reshape((s1,output_dim))
  yhat=yhat_4.reshape((s1,output_dim))




  y_1_no=yhat[:,0]
  y_2_no=yhat[:,1]
  y_3_no=yhat[:,2]
  #y_4_no=yhat[:,3]
  #y_5_no=yhat[:,4]
  #y_6_no=yhat[:,5]
  #y_7_no=yhat[:,6]
  #y_8_no=yhat[:,7]
  #y_9_no=yhat[:,8]
  #y_10_no=yhat[:,9]


  y_1=y_1_no
  y_2=y_2_no
  y_3=y_3_no
  #y_4=y_4_no
  #y_5=y_5_no
  #y_6=y_6_no
  #y_7=y_7_no



  y_test_1=test_o[:,0]
  y_test_2=test_o[:,1]
  y_test_3=test_o[:,2]
  #y_test_4=test_o[:,3]
  #y_test_5=test_o[:,4]
  #y_test_6=test_o[:,5]
  #y_test_7=test_o[:,6]
  #y_test_8=test_o[:,7]
  #y_test_9=test_o[:,8]
  #y_test_10=test_o[:,9]





  #print(y_1.shape,y_test_1.shape)


  cutoff=6
  fs=200
  order=4

  nyq = 0.5 * fs
  ## filtering data ##
  def butter_lowpass_filter(data, cutoff, fs, order):
      normal_cutoff = cutoff / nyq
      # Get the filter coefficients
      b, a = butter(order, normal_cutoff, btype='low', analog=False)
      y = filtfilt(b, a, data)
      return y



  # y_1=butter_lowpass_filter(y_1_no, cutoff, fs, order)
  # y_2=butter_lowpass_filter(y_2_no, cutoff, fs, order)
  # y_3=butter_lowpass_filter(y_3_no, cutoff, fs, order)
  # y_4=butter_lowpass_filter(y_4_no, cutoff, fs, order)
  # y_5=butter_lowpass_filter(y_5_no, cutoff, fs, order)
  # y_6=butter_lowpass_filter(y_6_no, cutoff, fs, order)
  # y_7=butter_lowpass_filter(y_7_no, cutoff, fs, order)
  #y_8=butter_lowpass_filter(y_8_no, cutoff, fs, order)
  #y_9=butter_lowpass_filter(y_9_no, cutoff, fs, order)
  #y_10=butter_lowpass_filter(y_10_no, cutoff, fs, order)




  Z_1=y_1
  Z_2=y_2
  Z_3=y_3
  #Z_4=y_4
  #Z_5=y_5
  #Z_6=y_6
  #Z_7=y_7
  #Z_8=y_8
  #Z_9=y_9
  #Z_10=y_10



  ###calculate RMSE

  rmse_1 =((np.sqrt(mean_squared_error(y_test_1,y_1)))/(max(y_test_1)-min(y_test_1)))*100
  rmse_2 =((np.sqrt(mean_squared_error(y_test_2,y_2)))/(max(y_test_2)-min(y_test_2)))*100
  rmse_3 =((np.sqrt(mean_squared_error(y_test_3,y_3)))/(max(y_test_3)-min(y_test_3)))*100
  #rmse_4 =((np.sqrt(mean_squared_error(y_test_4,y_4)))/(max(y_test_4)-min(y_test_4)))*100
  #rmse_5 =((np.sqrt(mean_squared_error(y_test_5,y_5)))/(max(y_test_5)-min(y_test_5)))*100
  #rmse_6 =((np.sqrt(mean_squared_error(y_test_6,y_6)))/(max(y_test_6)-min(y_test_6)))*100
  #rmse_7 =((np.sqrt(mean_squared_error(y_test_7,y_7)))/(max(y_test_7)-min(y_test_7)))*100
  #rmse_8 =((np.sqrt(mean_squared_error(y_test_8,y_8)))/(max(y_test_8)-min(y_test_8)))*100
  #rmse_9 =((np.sqrt(mean_squared_error(y_test_9,y_9)))/(max(y_test_9)-min(y_test_9)))*100
  #rmse_10 =((np.sqrt(mean_squared_error(y_test_10,y_10)))/(max(y_test_10)-min(y_test_10)))*100


  print(rmse_1)
  print(rmse_2)
  print(rmse_3)
  #print(rmse_4)
  #print(rmse_5)
  #print(rmse_6)
  #print(rmse_7)
  #print(rmse_8)
  #print(rmse_9)
  #print(rmse_10)


  p_1=np.corrcoef(y_1, y_test_1)[0, 1]
  p_2=np.corrcoef(y_2, y_test_2)[0, 1]
  p_3=np.corrcoef(y_3, y_test_3)[0, 1]
  #p_4=np.corrcoef(y_4, y_test_4)[0, 1]
  #p_5=np.corrcoef(y_5, y_test_5)[0, 1]
  #p_6=np.corrcoef(y_6, y_test_6)[0, 1]
  #p_7=np.corrcoef(y_7, y_test_7)[0, 1]
  #p_8=np.corrcoef(y_8, y_test_8)[0, 1]
  #p_9=np.corrcoef(y_9, y_test_9)[0, 1]
  #p_10=np.corrcoef(y_10, y_test_10)[0, 1]


  print("\n")
  print(p_1)
  print(p_2)
  print(p_3)
  #print(p_4)
  #print(p_5)
  #print(p_6)
  #print(p_7)
  #print(p_8)
  #print(p_9)
  #print(p_10)


              ### Correlation ###
  p=np.array([p_1,p_2,p_3])
  #,p_4,p_5,p_6,p_7])




      #### Mean and standard deviation ####

  rmse=np.array([rmse_1,rmse_2,rmse_3])
  #,rmse_4,rmse_5,rmse_6,rmse_7])

      #### Mean and standard deviation ####
  m=statistics.mean(rmse)
  SD=statistics.stdev(rmse)
  print('Mean: %.3f' % m,'+/- %.3f' %SD)

  m_c=statistics.mean(p)
  SD_c=statistics.stdev(p)
  print('Mean: %.3f' % m_c,'+/- %.3f' %SD_c)



  return rmse, p, Z_1,Z_2,Z_3
  #,Z_4,Z_5,Z_6,Z_7



############################################################################################################################################################################################################################################################################################################################################################################################################################################################################

# %%
#RMSELoss
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()

    def forward(self, pred, target):
        mse = nn.MSELoss()(pred, target)
        rmse = torch.sqrt(mse)
        return rmse

# %%
#DEVICE
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()

# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Teacher Model Training -- IMU-EMG

# %% [markdown]
# ## Training Function

# %%
import torch
import time
import matplotlib.pyplot as plt

def train_mm_teacher(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            output, x_1 = model(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())
            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for (data_acc, data_gyr, target, data_EMG) in val_loader:
                output, x_1 = model(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Teacher Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
#variable w needs to be checked for correct value, stand-in value used
class teacher(nn.Module):
    def __init__(self, input_acc, input_gyr, input_emg, drop_prob=0.25, w=100):
        super(teacher, self).__init__()

        self.w=w
        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)
        self.encoder_1_emg=Encoder_1(input_emg, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)
        self.encoder_2_emg=Encoder_2(input_emg, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)
        self.BN_emg= nn.BatchNorm1d(input_emg, affine=False)


        self.fc = nn.Linear(2*3*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)
        self.gate_3=GatingModule(128)

        self.fc_kd = nn.Linear(3*128, 2*128)

               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(3*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*3, 3*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*3*128+128, 2*3*128+128), nn.Sigmoid())

        self.pool = nn.MaxPool1d(kernel_size=2)


    def forward(self, x_acc, x_gyr, x_emg):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))
        x_emg_1=x_emg.view(x_emg.size(0)*x_emg.size(1),x_emg.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)
        x_emg_1=self.BN_emg(x_emg_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))
        x_emg_2=x_emg_1.view(-1, self.w, x_emg_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)
        x_emg_1=self.encoder_1_emg(x_emg_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)
        x_emg_2=self.encoder_2_emg(x_emg_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)
        # x_emg=torch.cat((x_emg_1,x_emg_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)
        x_emg=self.gate_3(x_emg_1,x_emg_2)

        x=torch.cat((x_acc,x_gyr,x_emg),dim=-1)
        x_kd=self.fc_kd(x)


        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        weights_3 = self.weighted_feat(x[:,:,2*128:3*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        x_3=weights_3*x[:,:,2*128:3*128]
        out_3=x_1+x_2+x_3

        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        #print(out.shape)
        return out,x_kd

# %%
lr = 0.001
model = teacher(18,18,3)

mm_teacher = train_mm_teacher(device, train_loader, val_loader, lr,40, model, filename ='model_teacher.pth')
# Out:
# Epoch: 1, time: 11.7514, Training Loss: 46.6769, Validation Loss: 37.1116
# Epoch: 2, time: 11.6004, Training Loss: 30.7550, Validation Loss: 29.4234
# Epoch: 3, time: 11.7946, Training Loss: 25.9304, Validation Loss: 26.2227
# Epoch: 4, time: 12.0200, Training Loss: 23.2807, Validation Loss: 23.8072
# Epoch: 5, time: 12.0061, Training Loss: 21.7743, Validation Loss: 22.9259
# Epoch: 6, time: 11.8788, Training Loss: 20.9923, Validation Loss: 22.1758
# Epoch: 7, time: 11.7894, Training Loss: 20.1439, Validation Loss: 21.7489
# Epoch: 8, time: 11.7348, Training Loss: 19.0894, Validation Loss: 20.5844
# Epoch: 9, time: 11.7341, Training Loss: 18.7430, Validation Loss: 20.3608
# Epoch: 10, time: 11.7370, Training Loss: 17.9911, Validation Loss: 19.4651
# Epoch: 11, time: 11.7977, Training Loss: 17.5875, Validation Loss: 19.5698
# Epoch: 12, time: 11.8390, Training Loss: 17.4391, Validation Loss: 18.7394
# Epoch: 13, time: 11.8464, Training Loss: 17.2093, Validation Loss: 19.3337
# Epoch: 14, time: 11.8551, Training Loss: 15.9099, Validation Loss: 17.3255
# Epoch: 15, time: 11.8605, Training Loss: 15.9152, Validation Loss: 18.8809
# Epoch: 16, time: 11.8325, Training Loss: 15.1767, Validation Loss: 17.8052
# Epoch: 17, time: 11.8255, Training Loss: 14.3388, Validation Loss: 16.0840
# Epoch: 18, time: 11.8115, Training Loss: 13.8157, Validation Loss: 17.7788
# Epoch: 19, time: 11.8205, Training Loss: 14.1760, Validation Loss: 18.5101
# Epoch: 20, time: 11.8154, Training Loss: 14.4159, Validation Loss: 17.5022
# Epoch: 21, time: 11.8284, Training Loss: 13.9934, Validation Loss: 16.7174
# Epoch: 22, time: 11.8495, Training Loss: 13.2256, Validation Loss: 15.2451
# Epoch: 23, time: 11.8432, Training Loss: 13.3623, Validation Loss: 16.0946
# Epoch: 24, time: 11.8495, Training Loss: 12.2453, Validation Loss: 16.1659
# Epoch: 25, time: 11.8098, Training Loss: 13.2091, Validation Loss: 15.6610
# Epoch: 26, time: 11.8315, Training Loss: 12.6497, Validation Loss: 13.3044
# Epoch: 27, time: 11.8129, Training Loss: 11.8147, Validation Loss: 15.2199
# Epoch: 28, time: 11.7909, Training Loss: 11.5678, Validation Loss: 14.2495
# Epoch: 29, time: 11.7968, Training Loss: 11.4902, Validation Loss: 14.6160
# Epoch: 30, time: 11.7965, Training Loss: 11.2581, Validation Loss: 12.9524
# Epoch: 31, time: 11.7739, Training Loss: 10.7122, Validation Loss: 12.9044
# Epoch: 32, time: 11.7961, Training Loss: 9.9712, Validation Loss: 13.5910
# Epoch: 33, time: 11.8000, Training Loss: 10.9027, Validation Loss: 14.6887
# Epoch: 34, time: 11.7825, Training Loss: 10.5074, Validation Loss: 13.2799
# Epoch: 35, time: 11.7992, Training Loss: 10.2084, Validation Loss: 12.7902
# Epoch: 36, time: 11.7986, Training Loss: 10.1275, Validation Loss: 13.8260
# Epoch: 37, time: 11.7989, Training Loss: 10.6701, Validation Loss: 11.9078
# Epoch: 38, time: 11.7978, Training Loss: 10.3812, Validation Loss: 12.6196
# Epoch: 39, time: 11.7842, Training Loss: 9.2590, Validation Loss: 12.6480
# Epoch: 40, time: 11.7952, Training Loss: 9.5843, Validation Loss: 12.0670
# Training time: 473.210839509964 seconds

# %%
# Load the trained model
mm_teacher = teacher(18, 18, 3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)
mm_teacher.eval()

# Initialize variables to store predictions and targets
yhat_5 = None
test_target = None

# Iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        output, x_1 = mm_teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

        if i == 0:
            yhat_5 = output
            test_target = target
        else:
            yhat_5 = torch.cat((yhat_5, output), dim=0)
            test_target = torch.cat((test_target, target), dim=0)

        # Clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()

# Convert to numpy arrays for further processing
yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

print(yhat_4.shape)
print(test_target.shape)

# Flatten the data on the 0th dimension
yhat_4_flat = yhat_4.reshape(-1, yhat_4.shape[-1])
test_target_flat = test_target.reshape(-1, test_target.shape[-1])
# Out:
# 22.63404242425088
# 15.953500969305711
# 16.54577061173045
#
#
# 0.8199360722564775
# 0.6913589144497405
# 0.6787128681160891
# Mean: 18.378 +/- 3.698
# Mean: 0.730 +/- 0.078
# (1924, 100, 3)
# (1924, 100, 3)

# %%
# Plot predicted vs ground truth for each channel
num_dims = yhat_4_flat.shape[1]
start = 0
step = 3000
end = start + step
for dim in range(num_dims):
    plt.figure(figsize=(10, 6))
    plt.plot(test_target_flat[start:end, dim], label='Ground Truth')
    plt.plot(yhat_4_flat[start:end, dim], label='Predicted', linestyle='dashed')
    plt.title(f'Predicted vs Ground Truth - Dim {dim + 1}')
    plt.xlabel('Samples')
    plt.ylabel('Value')
    plt.ylim(-180, 180)
    plt.legend()
    plt.show()

# %%
# Load the trained model
mm_teacher = teacher(18, 18, 3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)
mm_teacher.eval()

# Initialize variables to store predictions and targets
yhat_5 = None
test_target = None

# Iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(val_loader):
        output, x_1 = mm_teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

        if i == 0:
            yhat_5 = output
            test_target = target
        else:
            yhat_5 = torch.cat((yhat_5, output), dim=0)
            test_target = torch.cat((test_target, target), dim=0)

        # Clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()

# Convert to numpy arrays for further processing
yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()


# rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

# Flatten the data on the 0th dimension
yhat_4_flat = yhat_4.reshape(-1, yhat_4.shape[-1])
test_target_flat = test_target.reshape(-1, test_target.shape[-1])

# Plot predicted vs ground truth for each channel
num_dims = yhat_4_flat.shape[1]
start = 0
step = 3000
end = start + step
for dim in range(num_dims):
    plt.figure(figsize=(10, 6))
    plt.plot(test_target_flat[start:end, dim], label='Ground Truth')
    plt.plot(yhat_4_flat[start:end, dim], label='Predicted', linestyle='dashed')
    plt.title(f'Predicted vs Ground Truth - Dim {dim + 1}')
    plt.xlabel('Samples')
    plt.ylabel('Value')
    plt.ylim(-180, 180)
    plt.legend()
    plt.show()

# # Additional concatenation of metrics
# ablation_1 = np.hstack([rmse, p])

# %%
#load csv
csv_file = '/content/drive/MyDrive/sd_datacollection/subject_10/combined/P010_T001_armSwing_slow_combined.csv'
df = pd.read_csv(csv_file)
df.head()

# Extract input and target data
input_acc = df[columns_imu_acc].values
input_gyr = df[columns_imu_gyr].values
input_emg = df[['IM EMG4', 'IM EMG5', 'IM EMG6']].values
target_data = df[columns_joints].values

# Create tensors
acc_tensor = torch.tensor(input_acc, dtype=torch.float32).unsqueeze(0)
gyr_tensor = torch.tensor(input_gyr, dtype=torch.float32).unsqueeze(0)
emg_tensor = torch.tensor(input_emg, dtype=torch.float32).unsqueeze(0)
target_tensor = torch.tensor(target_data, dtype=torch.float32).unsqueeze(0)

# Load the trained model
mm_teacher = teacher(18, 18, 3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)
mm_teacher.eval()

# Perform inference without overlapping windows
window_size = 100
predictions = []

with torch.no_grad():
    for i in range(0, acc_tensor.shape[1] - window_size + 1, window_size):
        acc_window = acc_tensor[:, i:i+window_size, :].to(device)
        gyr_window = gyr_tensor[:, i:i+window_size, :].to(device)
        emg_window = emg_tensor[:, i:i+window_size, :].to(device)

        output, _ = mm_teacher(acc_window, gyr_window, emg_window)
        predictions.append(output.cpu().numpy())

# Concatenate predictions along the time dimension to form a continuous time series
predictions = np.concatenate(predictions, axis=1)
predictions = predictions.reshape(-1, predictions.shape[-1])

# Ensure shapes are correct
target_tensor = target_tensor.cpu().numpy().squeeze(0)
print(f'Predictions shape: {predictions.shape}')
print(f'Target shape: {target_tensor.shape}')

# Plot predicted vs ground truth for each channel
num_channels = predictions.shape[1]

for channel in range(num_channels):
    plt.figure(figsize=(10, 6))
    plt.plot(target_tensor[:500, channel], label='Ground Truth')
    plt.plot(predictions[:500, channel], label='Predicted', linestyle='dashed')
    #print shape of each plot
    plt.title(f'Predicted vs Ground Truth - Channel {channel + 1}')
    plt.xlabel('Samples')
    plt.ylabel('Value')
    plt.ylim(-180, 180)
    plt.legend()
    plt.show()
# Out:
# Predictions shape: (3000, 3)
# Target shape: (3064, 3)

# %% [markdown]
# # Student Model-- 1 IMU

# %% [markdown]
# ## Training Function

# %%
def train_mm_student_1(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            output = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())
            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                output = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_1(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_1, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)

               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_1(3,3)

mm_student_1 = train_mm_student_1(device, train_loader, val_loader, lr,40,model,'model_student_1.pth')
# Out:
# Epoch: 1, time: 7.2763, Training Loss: 54.8118, Validation Loss: 53.2655
# Epoch: 2, time: 7.4049, Training Loss: 50.6369, Validation Loss: 51.3820
# Epoch: 3, time: 7.5004, Training Loss: 48.6217, Validation Loss: 49.4871
# Epoch: 4, time: 7.5877, Training Loss: 47.2717, Validation Loss: 48.0529
# Epoch: 5, time: 7.5406, Training Loss: 46.1665, Validation Loss: 46.9527
# Epoch: 6, time: 7.4612, Training Loss: 45.4079, Validation Loss: 46.6214
# Epoch: 7, time: 7.4139, Training Loss: 44.4861, Validation Loss: 45.4924
# Epoch: 8, time: 7.3474, Training Loss: 43.6785, Validation Loss: 44.7230
# Epoch: 9, time: 7.3525, Training Loss: 43.0388, Validation Loss: 44.2514
# Epoch: 10, time: 7.3399, Training Loss: 42.4500, Validation Loss: 43.5010
# Epoch: 11, time: 7.3224, Training Loss: 41.9242, Validation Loss: 42.7486
# Epoch: 12, time: 7.3224, Training Loss: 41.3618, Validation Loss: 42.9858
# Epoch: 13, time: 7.3563, Training Loss: 40.7585, Validation Loss: 42.3820
# Epoch: 14, time: 7.3575, Training Loss: 40.4385, Validation Loss: 41.9602
# Epoch: 15, time: 7.3734, Training Loss: 39.8733, Validation Loss: 41.6012
# Epoch: 16, time: 7.4110, Training Loss: 39.2241, Validation Loss: 41.0976
# Epoch: 17, time: 7.4113, Training Loss: 38.8156, Validation Loss: 40.6356
# Epoch: 18, time: 7.4425, Training Loss: 38.0220, Validation Loss: 40.6939
# Epoch: 19, time: 7.3927, Training Loss: 37.4636, Validation Loss: 39.9577
# Epoch: 20, time: 7.4104, Training Loss: 36.9796, Validation Loss: 39.7837
# Epoch: 21, time: 7.3909, Training Loss: 36.6405, Validation Loss: 39.9205
# Epoch: 22, time: 7.3864, Training Loss: 36.2309, Validation Loss: 39.0939
# Epoch: 23, time: 7.3861, Training Loss: 35.5680, Validation Loss: 38.9843
# Epoch: 24, time: 7.3559, Training Loss: 34.9980, Validation Loss: 38.9083
# Epoch: 25, time: 7.3786, Training Loss: 34.0309, Validation Loss: 37.8800
# Epoch: 26, time: 7.4029, Training Loss: 33.9371, Validation Loss: 38.0084
# Epoch: 27, time: 7.3960, Training Loss: 33.4994, Validation Loss: 37.5253
# Epoch: 28, time: 7.3867, Training Loss: 32.8131, Validation Loss: 38.0600
# Epoch: 29, time: 7.3865, Training Loss: 32.2545, Validation Loss: 37.3977
# Epoch: 30, time: 7.4012, Training Loss: 31.6592, Validation Loss: 37.2136
# Epoch: 31, time: 7.4022, Training Loss: 31.1485, Validation Loss: 37.0327
# Epoch: 32, time: 7.3955, Training Loss: 30.9044, Validation Loss: 35.4736
# Epoch: 33, time: 7.4017, Training Loss: 30.3529, Validation Loss: 35.2795
# Epoch: 34, time: 7.4019, Training Loss: 29.6991, Validation Loss: 35.0960
# Epoch: 35, time: 7.4123, Training Loss: 29.2311, Validation Loss: 35.0780
# Epoch: 36, time: 7.4087, Training Loss: 28.3589, Validation Loss: 34.7620
# Epoch: 37, time: 7.4010, Training Loss: 28.0378, Validation Loss: 34.3377
# Epoch: 38, time: 7.3913, Training Loss: 28.0074, Validation Loss: 33.3575
# Epoch: 39, time: 7.4093, Training Loss: 27.5259, Validation Loss: 32.7220
# Epoch: 40, time: 7.4025, Training Loss: 26.8131, Validation Loss: 33.5482
# Training time: 296.6371877193451 seconds

# %%
mm_student_1= student_1(3,3)
mm_student_1.load_state_dict(torch.load('model_student_1.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, ( data_acc, data_gyr,  target, data_EMG) in enumerate(test_loader):
        output = mm_student_1(data_acc[:,:,0:3].to(device).float(),data_gyr[:,:,0:3].to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

#fix
rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target, output_dim=3)

ablation_2=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 23.571376121614147
# 19.79384721408508
# 22.725821291178523
#
#
# 0.4833948006905633
# 0.3956071927513775
# 0.3750995685887868
# Mean: 22.030 +/- 1.982
# Mean: 0.418 +/- 0.058

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
"""## Knowledge distillation"""

def train_student_1(device, alpha, beta, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            student_output, x_student_1 = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                output, student_1 = model(data_acc[:, :, 0:3].to(device).float(), data_gyr[:, :, 0:3].to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_1_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_1_KD, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)



               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_1_KD(3,3)

teacher_trained= teacher(18,18,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)
alpha=0.01
beta=0.01

student_KD= train_student_1(device, alpha, beta, train_loader, val_loader, lr,40, student, 'student_1_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 11.7414, Training Loss: 54.8474, Validation Loss: 53.3529
# Epoch: 2, time: 11.9204, Training Loss: 50.9115, Validation Loss: 51.4711
# Epoch: 3, time: 12.0977, Training Loss: 49.2612, Validation Loss: 49.6563
# Epoch: 4, time: 11.9435, Training Loss: 47.9864, Validation Loss: 48.6343
# Epoch: 5, time: 11.7858, Training Loss: 46.7201, Validation Loss: 47.6295
# Epoch: 6, time: 11.6942, Training Loss: 45.7035, Validation Loss: 46.7909
# Epoch: 7, time: 11.6776, Training Loss: 44.8400, Validation Loss: 46.1544
# Epoch: 8, time: 11.7032, Training Loss: 44.0098, Validation Loss: 45.4125
# Epoch: 9, time: 11.7622, Training Loss: 43.3002, Validation Loss: 44.6034
# Epoch: 10, time: 11.8314, Training Loss: 42.5750, Validation Loss: 43.9464
# Epoch: 11, time: 11.8576, Training Loss: 41.9843, Validation Loss: 43.8176
# Epoch: 12, time: 11.8201, Training Loss: 41.5990, Validation Loss: 43.8909
# Epoch: 13, time: 11.8019, Training Loss: 40.9568, Validation Loss: 43.1049
# Epoch: 14, time: 11.7915, Training Loss: 40.3865, Validation Loss: 42.6818
# Epoch: 15, time: 11.7692, Training Loss: 39.9799, Validation Loss: 42.5436
# Epoch: 16, time: 11.7829, Training Loss: 39.5036, Validation Loss: 42.0952
# Epoch: 17, time: 11.7937, Training Loss: 38.7816, Validation Loss: 41.4285
# Epoch: 18, time: 11.8098, Training Loss: 38.0893, Validation Loss: 41.0547
# Epoch: 19, time: 11.8198, Training Loss: 37.6375, Validation Loss: 41.0015
# Epoch: 20, time: 11.8166, Training Loss: 36.8471, Validation Loss: 40.9877
# Epoch: 21, time: 11.8201, Training Loss: 36.2224, Validation Loss: 40.5267
# Epoch: 22, time: 11.8158, Training Loss: 35.8215, Validation Loss: 40.0085
# Epoch: 23, time: 11.8001, Training Loss: 35.3485, Validation Loss: 38.9884
# Epoch: 24, time: 11.8054, Training Loss: 34.7924, Validation Loss: 38.5933
# Epoch: 25, time: 11.8008, Training Loss: 34.2673, Validation Loss: 38.8327
# Epoch: 26, time: 11.8207, Training Loss: 33.5564, Validation Loss: 38.6223
# Epoch: 27, time: 11.8068, Training Loss: 32.9786, Validation Loss: 37.5626
# Epoch: 28, time: 11.7994, Training Loss: 32.6439, Validation Loss: 37.5954
# Epoch: 29, time: 11.8174, Training Loss: 32.1830, Validation Loss: 36.7657
# Epoch: 30, time: 11.8251, Training Loss: 31.4526, Validation Loss: 37.3489
# Epoch: 31, time: 11.8263, Training Loss: 30.9332, Validation Loss: 36.9715
# Epoch: 32, time: 11.8198, Training Loss: 30.4230, Validation Loss: 36.4369
# Epoch: 33, time: 11.8212, Training Loss: 31.1642, Validation Loss: 36.5321
# Epoch: 34, time: 11.8059, Training Loss: 29.9778, Validation Loss: 36.2614
# Epoch: 35, time: 11.7923, Training Loss: 29.3523, Validation Loss: 36.3152
# Epoch: 36, time: 11.8102, Training Loss: 28.9711, Validation Loss: 35.5967
# Epoch: 37, time: 11.8348, Training Loss: 28.8395, Validation Loss: 35.5233
# Epoch: 38, time: 11.8303, Training Loss: 27.9662, Validation Loss: 35.5329
# Epoch: 39, time: 11.8202, Training Loss: 27.6573, Validation Loss: 33.6953
# Epoch: 40, time: 11.8144, Training Loss: 27.2212, Validation Loss: 34.3698
# Training time: 473.1558997631073 seconds

# %%
mm_student_1= student_1_KD(3,3)
mm_student_1.load_state_dict(torch.load('student_1_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, ( data_acc, data_gyr,  target,data_EMG) in enumerate(test_loader):
        output,student_1 = mm_student_1(data_acc[:,:,0:3].to(device).float(),data_gyr[:,:,0:3].to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, data_EMG, target,output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_3=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 26.06425660379387
# 20.762973385201946
# 21.53631951182777
#
#
# 0.46778173140199325
# 0.3523868304051986
# 0.4332677485246483
# Mean: 22.788 +/- 2.864
# Mean: 0.418 +/- 0.059

# %% [markdown]
# # Student Model-- 2 IMUs

# %% [markdown]
# ## Training Function

# %%
def train_mm_student_2(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
            data_gyr = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
            output = model(data_acc.to(device).float(), data_gyr.to(device).float())

            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
                data_gyr = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
                output = model(data_acc.to(device).float(), data_gyr.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_2(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_2, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


        # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_2(6,6)

mm_student_2 = train_mm_student_2(device, train_loader, val_loader, lr,40,model,'model_student_2.pth')
# Out:
# Epoch: 1, time: 7.4107, Training Loss: 53.4733, Validation Loss: 50.2152
# Epoch: 2, time: 7.4058, Training Loss: 43.8375, Validation Loss: 41.8760
# Epoch: 3, time: 7.5276, Training Loss: 37.2914, Validation Loss: 35.0412
# Epoch: 4, time: 7.6138, Training Loss: 32.7319, Validation Loss: 32.1353
# Epoch: 5, time: 7.6217, Training Loss: 29.7391, Validation Loss: 29.0465
# Epoch: 6, time: 7.5463, Training Loss: 27.3959, Validation Loss: 26.9419
# Epoch: 7, time: 7.4645, Training Loss: 25.5256, Validation Loss: 25.7270
# Epoch: 8, time: 7.4233, Training Loss: 23.9777, Validation Loss: 24.9986
# Epoch: 9, time: 7.3747, Training Loss: 23.0658, Validation Loss: 23.7308
# Epoch: 10, time: 7.3593, Training Loss: 21.9807, Validation Loss: 23.0022
# Epoch: 11, time: 7.3492, Training Loss: 20.8628, Validation Loss: 22.3402
# Epoch: 12, time: 7.3618, Training Loss: 20.5952, Validation Loss: 22.9955
# Epoch: 13, time: 7.3905, Training Loss: 19.8863, Validation Loss: 22.8878
# Epoch: 14, time: 7.4250, Training Loss: 19.9969, Validation Loss: 22.5840
# Epoch: 15, time: 7.4454, Training Loss: 19.0269, Validation Loss: 21.4350
# Epoch: 16, time: 7.4441, Training Loss: 18.0945, Validation Loss: 20.1975
# Epoch: 17, time: 7.4615, Training Loss: 17.6962, Validation Loss: 19.9705
# Epoch: 18, time: 7.4518, Training Loss: 17.1028, Validation Loss: 20.0243
# Epoch: 19, time: 7.4564, Training Loss: 16.4404, Validation Loss: 18.4598
# Epoch: 20, time: 7.4390, Training Loss: 16.1288, Validation Loss: 18.5205
# Epoch: 21, time: 7.4201, Training Loss: 16.3282, Validation Loss: 18.0389
# Epoch: 22, time: 7.4192, Training Loss: 15.4284, Validation Loss: 17.7832
# Epoch: 23, time: 7.4023, Training Loss: 15.0980, Validation Loss: 17.8579
# Epoch: 24, time: 7.4126, Training Loss: 14.7823, Validation Loss: 16.6307
# Epoch: 25, time: 7.3899, Training Loss: 13.7831, Validation Loss: 16.8496
# Epoch: 26, time: 7.4287, Training Loss: 13.7506, Validation Loss: 15.9116
# Epoch: 27, time: 7.4328, Training Loss: 14.2942, Validation Loss: 17.1866
# Epoch: 28, time: 7.4298, Training Loss: 14.3726, Validation Loss: 15.6858
# Epoch: 29, time: 7.4414, Training Loss: 13.1612, Validation Loss: 14.7935
# Epoch: 30, time: 7.4209, Training Loss: 12.4862, Validation Loss: 14.3961
# Epoch: 31, time: 7.4550, Training Loss: 12.6518, Validation Loss: 14.4306
# Epoch: 32, time: 7.4353, Training Loss: 12.6939, Validation Loss: 15.2517
# Epoch: 33, time: 7.4424, Training Loss: 12.6987, Validation Loss: 16.1477
# Epoch: 34, time: 7.4466, Training Loss: 12.3279, Validation Loss: 14.9663
# Epoch: 35, time: 7.4345, Training Loss: 12.4634, Validation Loss: 13.7373
# Epoch: 36, time: 7.4383, Training Loss: 11.8873, Validation Loss: 12.6148
# Epoch: 37, time: 7.4178, Training Loss: 11.1036, Validation Loss: 13.1379
# Epoch: 38, time: 7.4358, Training Loss: 10.9917, Validation Loss: 13.3573
# Epoch: 39, time: 7.4186, Training Loss: 11.3452, Validation Loss: 13.3142
# Epoch: 40, time: 7.4451, Training Loss: 11.0914, Validation Loss: 13.1273
# Training time: 298.05189085006714 seconds

# %%
mm_student_2= student_2(6,6)
mm_student_2.load_state_dict(torch.load('model_student_2.pth'))
mm_student_2.to(device)

mm_student_2.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:3],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:3],data_gyr[:,:,9:12]),dim=-1)
        output = mm_student_2(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_4=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 18.585262582375087
# 19.687947551410716
# 18.333751055903093
#
#
# 0.8109628329220286
# 0.42496139356558865
# 0.5810426880202526
# Mean: 18.869 +/- 0.720
# Mean: 0.606 +/- 0.194

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
def train_student_2(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc_1 = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
            data_gyr_1 = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
            student_output, x_student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc_1 = torch.cat((data_acc[:, :, 0:3], data_acc[:, :, 9:12]), dim=-1)
                data_gyr_1 = torch.cat((data_gyr[:, :, 0:3], data_gyr[:, :, 9:12]), dim=-1)
                output, student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_2_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_2_KD, self).__init__()
        self.w=w
        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_2_KD(6,6)

teacher_trained= teacher(18,18,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)


student_KD= train_student_2(device, train_loader, val_loader, lr,40, student, 'student_2_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 11.8933, Training Loss: 53.5454, Validation Loss: 50.2347
# Epoch: 2, time: 12.0402, Training Loss: 43.6042, Validation Loss: 40.7026
# Epoch: 3, time: 12.1447, Training Loss: 36.5017, Validation Loss: 34.2723
# Epoch: 4, time: 11.9830, Training Loss: 32.1494, Validation Loss: 30.8794
# Epoch: 5, time: 11.8153, Training Loss: 28.8340, Validation Loss: 29.3303
# Epoch: 6, time: 11.7464, Training Loss: 26.9295, Validation Loss: 27.0806
# Epoch: 7, time: 11.7197, Training Loss: 25.3004, Validation Loss: 26.4854
# Epoch: 8, time: 11.7708, Training Loss: 24.3490, Validation Loss: 25.3352
# Epoch: 9, time: 11.8580, Training Loss: 23.1248, Validation Loss: 24.0456
# Epoch: 10, time: 11.9093, Training Loss: 22.1808, Validation Loss: 23.7801
# Epoch: 11, time: 11.9318, Training Loss: 21.1824, Validation Loss: 22.8422
# Epoch: 12, time: 11.9065, Training Loss: 20.3390, Validation Loss: 22.5152
# Epoch: 13, time: 11.8652, Training Loss: 20.3953, Validation Loss: 22.3971
# Epoch: 14, time: 11.8340, Training Loss: 18.8725, Validation Loss: 21.5299
# Epoch: 15, time: 11.8312, Training Loss: 18.3966, Validation Loss: 20.9353
# Epoch: 16, time: 11.8443, Training Loss: 17.9812, Validation Loss: 20.4854
# Epoch: 17, time: 11.8545, Training Loss: 17.5936, Validation Loss: 19.9408
# Epoch: 18, time: 11.8572, Training Loss: 16.8656, Validation Loss: 19.6173
# Epoch: 19, time: 11.8577, Training Loss: 16.5732, Validation Loss: 20.4684
# Epoch: 20, time: 11.8769, Training Loss: 16.5511, Validation Loss: 19.3506
# Epoch: 21, time: 11.8828, Training Loss: 16.1801, Validation Loss: 18.9308
# Epoch: 22, time: 11.8741, Training Loss: 15.6607, Validation Loss: 17.6248
# Epoch: 23, time: 11.8758, Training Loss: 14.6545, Validation Loss: 17.9325
# Epoch: 24, time: 11.8782, Training Loss: 14.0711, Validation Loss: 17.9317
# Epoch: 25, time: 11.8723, Training Loss: 14.2019, Validation Loss: 18.9246
# Epoch: 26, time: 11.8633, Training Loss: 14.2054, Validation Loss: 17.2634
# Epoch: 27, time: 11.8698, Training Loss: 13.7194, Validation Loss: 16.3580
# Epoch: 28, time: 11.8746, Training Loss: 13.4345, Validation Loss: 17.5525
# Epoch: 29, time: 11.8674, Training Loss: 12.9374, Validation Loss: 16.7880
# Epoch: 30, time: 11.8658, Training Loss: 14.2680, Validation Loss: 18.0787
# Epoch: 31, time: 11.8782, Training Loss: 13.4064, Validation Loss: 15.5606
# Epoch: 32, time: 11.8566, Training Loss: 12.3072, Validation Loss: 16.1678
# Epoch: 33, time: 11.8725, Training Loss: 12.9122, Validation Loss: 16.1536
# Epoch: 34, time: 11.8620, Training Loss: 12.8262, Validation Loss: 14.7952
# Epoch: 35, time: 11.8744, Training Loss: 11.7516, Validation Loss: 14.2904
# Epoch: 36, time: 11.8615, Training Loss: 11.4787, Validation Loss: 13.3767
# Epoch: 37, time: 11.8594, Training Loss: 11.1349, Validation Loss: 14.0503
# Epoch: 38, time: 11.8691, Training Loss: 11.6995, Validation Loss: 14.7637
# Epoch: 39, time: 11.8604, Training Loss: 11.9605, Validation Loss: 14.7926
# Epoch: 40, time: 11.8750, Training Loss: 11.8355, Validation Loss: 14.8185
# Training time: 475.5317084789276 seconds

# %%
mm_student_1= student_2_KD(6,6)
mm_student_1.load_state_dict(torch.load('student_2_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:3],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:3],data_gyr[:,:,9:12]),dim=-1)
        output,student_1 = mm_student_1(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_5=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 22.116770263921506
# 19.46397454627003
# 19.145306509401877
#
#
# 0.7426106022879821
# 0.48058757952033876
# 0.5492937211055438
# Mean: 20.242 +/- 1.631
# Mean: 0.591 +/- 0.136

# %% [markdown]
# # Student Model-- 3 IMUs

# %% [markdown]
# ## Training Function

# %%
def train_mm_student_3(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
            data_gyr = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
            output = model(data_acc.to(device).float(), data_gyr.to(device).float())

            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
                data_gyr = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
                output = model(data_acc.to(device).float(), data_gyr.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_3(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_3, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_3(9,9)

mm_student_3 = train_mm_student_3(device, train_loader, val_loader, lr,40,model,'model_student_3.pth')
# Out:
# Epoch: 1, time: 7.5877, Training Loss: 52.8775, Validation Loss: 48.3412
# Epoch: 2, time: 7.6121, Training Loss: 42.3816, Validation Loss: 39.1098
# Epoch: 3, time: 7.7039, Training Loss: 33.6323, Validation Loss: 32.1811
# Epoch: 4, time: 7.6656, Training Loss: 29.0245, Validation Loss: 28.7436
# Epoch: 5, time: 7.5855, Training Loss: 25.9774, Validation Loss: 26.1085
# Epoch: 6, time: 7.5183, Training Loss: 23.8476, Validation Loss: 24.8956
# Epoch: 7, time: 7.4378, Training Loss: 22.7700, Validation Loss: 24.4494
# Epoch: 8, time: 7.3995, Training Loss: 21.9746, Validation Loss: 25.1351
# Epoch: 9, time: 7.3851, Training Loss: 21.3557, Validation Loss: 23.0673
# Epoch: 10, time: 7.4101, Training Loss: 20.4103, Validation Loss: 21.7831
# Epoch: 11, time: 7.3985, Training Loss: 19.1447, Validation Loss: 21.1568
# Epoch: 12, time: 7.4494, Training Loss: 18.6001, Validation Loss: 21.9514
# Epoch: 13, time: 7.4881, Training Loss: 18.2953, Validation Loss: 21.6257
# Epoch: 14, time: 7.5009, Training Loss: 17.8598, Validation Loss: 20.2327
# Epoch: 15, time: 7.5242, Training Loss: 16.8267, Validation Loss: 19.9363
# Epoch: 16, time: 7.5048, Training Loss: 16.2626, Validation Loss: 19.8400
# Epoch: 17, time: 7.5257, Training Loss: 16.3794, Validation Loss: 20.0652
# Epoch: 18, time: 7.5051, Training Loss: 16.1573, Validation Loss: 19.0208
# Epoch: 19, time: 7.4995, Training Loss: 15.1320, Validation Loss: 18.0228
# Epoch: 20, time: 7.4835, Training Loss: 14.3072, Validation Loss: 17.2222
# Epoch: 21, time: 7.4568, Training Loss: 14.3509, Validation Loss: 17.6983
# Epoch: 22, time: 7.4764, Training Loss: 14.3964, Validation Loss: 17.4899
# Epoch: 23, time: 7.4494, Training Loss: 13.8445, Validation Loss: 16.8703
# Epoch: 24, time: 7.4711, Training Loss: 13.0435, Validation Loss: 14.8560
# Epoch: 25, time: 7.4718, Training Loss: 13.3494, Validation Loss: 16.4949
# Epoch: 26, time: 7.4767, Training Loss: 13.2018, Validation Loss: 15.5239
# Epoch: 27, time: 7.4946, Training Loss: 12.8597, Validation Loss: 15.0362
# Epoch: 28, time: 7.4930, Training Loss: 12.4172, Validation Loss: 16.0444
# Epoch: 29, time: 7.4895, Training Loss: 12.0017, Validation Loss: 14.3619
# Epoch: 30, time: 7.4821, Training Loss: 11.9909, Validation Loss: 14.9211
# Epoch: 31, time: 7.4900, Training Loss: 11.8328, Validation Loss: 15.7340
# Epoch: 32, time: 7.4835, Training Loss: 11.7474, Validation Loss: 14.4555
# Epoch: 33, time: 7.5100, Training Loss: 11.4529, Validation Loss: 13.3377
# Epoch: 34, time: 7.4970, Training Loss: 11.8601, Validation Loss: 14.3453
# Epoch: 35, time: 7.4925, Training Loss: 11.1834, Validation Loss: 13.7122
# Epoch: 36, time: 7.4889, Training Loss: 10.0697, Validation Loss: 12.3536
# Epoch: 37, time: 7.4693, Training Loss: 10.8006, Validation Loss: 12.5069
# Epoch: 38, time: 7.4919, Training Loss: 10.0561, Validation Loss: 12.1057
# Epoch: 39, time: 7.4738, Training Loss: 9.6442, Validation Loss: 13.8600
# Epoch: 40, time: 7.4780, Training Loss: 10.1884, Validation Loss: 13.6339
# Training time: 300.28558373451233 seconds

# %%
mm_student_3= student_3(9,9)
mm_student_3.load_state_dict(torch.load('model_student_3.pth'))
mm_student_3.to(device)

mm_student_3.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:6],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:6],data_gyr[:,:,9:12]),dim=-1)
        output = mm_student_3(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_6=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 19.512530773058657
# 19.280206693114604
# 17.38464784294965
#
#
# 0.7882925170905358
# 0.6042526282270315
# 0.6552902569845266
# Mean: 18.726 +/- 1.167
# Mean: 0.683 +/- 0.095

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
def train_student_3(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc_1 = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
            data_gyr_1 = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
            student_output, x_student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc_1 = torch.cat((data_acc[:, :, 0:6], data_acc[:, :, 9:12]), dim=-1)
                data_gyr_1 = torch.cat((data_gyr[:, :, 0:6], data_gyr[:, :, 9:12]), dim=-1)
                output, student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_3_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_3_KD, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_3_KD(9,9)

teacher_trained= teacher(18,18,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)


student_KD= train_student_3(device, train_loader, val_loader, lr,40, student, 'student_3_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 12.3466, Training Loss: 53.0566, Validation Loss: 49.6162
# Epoch: 2, time: 13.0183, Training Loss: 42.7924, Validation Loss: 40.3662
# Epoch: 3, time: 11.9931, Training Loss: 34.3233, Validation Loss: 30.7055
# Epoch: 4, time: 11.8348, Training Loss: 28.9145, Validation Loss: 28.7070
# Epoch: 5, time: 11.7562, Training Loss: 26.3772, Validation Loss: 25.8940
# Epoch: 6, time: 11.7547, Training Loss: 23.9972, Validation Loss: 24.1564
# Epoch: 7, time: 11.8375, Training Loss: 22.8916, Validation Loss: 23.6476
# Epoch: 8, time: 11.9278, Training Loss: 21.8567, Validation Loss: 22.7638
# Epoch: 9, time: 11.9616, Training Loss: 20.8834, Validation Loss: 22.3741
# Epoch: 10, time: 11.9824, Training Loss: 20.2081, Validation Loss: 21.5984
# Epoch: 11, time: 11.9276, Training Loss: 19.2810, Validation Loss: 22.0507
# Epoch: 12, time: 11.9261, Training Loss: 18.6672, Validation Loss: 20.8042
# Epoch: 13, time: 11.8659, Training Loss: 18.1432, Validation Loss: 20.7727
# Epoch: 14, time: 11.8748, Training Loss: 18.7910, Validation Loss: 20.8361
# Epoch: 15, time: 11.9218, Training Loss: 17.3475, Validation Loss: 19.2805
# Epoch: 16, time: 11.8944, Training Loss: 16.9001, Validation Loss: 19.0255
# Epoch: 17, time: 11.8927, Training Loss: 16.8995, Validation Loss: 18.1830
# Epoch: 18, time: 11.9181, Training Loss: 15.7443, Validation Loss: 18.1610
# Epoch: 19, time: 11.9125, Training Loss: 15.6385, Validation Loss: 18.0318
# Epoch: 20, time: 11.9247, Training Loss: 14.7498, Validation Loss: 18.4086
# Epoch: 21, time: 11.9152, Training Loss: 14.7925, Validation Loss: 17.1003
# Epoch: 22, time: 11.9182, Training Loss: 14.7240, Validation Loss: 16.9751
# Epoch: 23, time: 11.9233, Training Loss: 13.9020, Validation Loss: 16.2665
# Epoch: 24, time: 11.9081, Training Loss: 12.8690, Validation Loss: 16.3824
# Epoch: 25, time: 11.9246, Training Loss: 12.8028, Validation Loss: 16.4055
# Epoch: 26, time: 11.9244, Training Loss: 12.9719, Validation Loss: 16.3520
# Epoch: 27, time: 11.9162, Training Loss: 12.4500, Validation Loss: 15.5919
# Epoch: 28, time: 11.9072, Training Loss: 12.7106, Validation Loss: 15.0685
# Epoch: 29, time: 11.9111, Training Loss: 12.6559, Validation Loss: 13.8503
# Epoch: 30, time: 11.9021, Training Loss: 12.4306, Validation Loss: 15.2857
# Epoch: 31, time: 11.9106, Training Loss: 12.1493, Validation Loss: 14.8735
# Epoch: 32, time: 11.9178, Training Loss: 12.2185, Validation Loss: 14.2363
# Epoch: 33, time: 11.9103, Training Loss: 12.3140, Validation Loss: 15.0732
# Epoch: 34, time: 11.8909, Training Loss: 11.7892, Validation Loss: 14.0015
# Epoch: 35, time: 11.9107, Training Loss: 11.1120, Validation Loss: 13.6245
# Epoch: 36, time: 11.9093, Training Loss: 10.3249, Validation Loss: 12.8311
# Epoch: 37, time: 11.8970, Training Loss: 9.9113, Validation Loss: 13.6390
# Epoch: 38, time: 11.9168, Training Loss: 10.7406, Validation Loss: 13.4226
# Epoch: 39, time: 11.9264, Training Loss: 10.9563, Validation Loss: 12.5955
# Epoch: 40, time: 11.9332, Training Loss: 10.2432, Validation Loss: 13.8556
# Training time: 478.3116593360901 seconds

# %%
mm_student_1= student_3_KD(9,9)
mm_student_1.load_state_dict(torch.load('student_3_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:6],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:6],data_gyr[:,:,9:12]),dim=-1)
        output,student_1 = mm_student_1(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_7=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 22.839509307190443
# 18.914165205873445
# 17.94827350650376
#
#
# 0.765853432056544
# 0.5619290095469519
# 0.6102592312022318
# Mean: 19.901 +/- 2.591
# Mean: 0.646 +/- 0.107

# %% [markdown]
# # Student Model-- 4 IMUs

# %% [markdown]
# ## Training Function

# %%
import torch
import time
import matplotlib.pyplot as plt

def train_mm_student_4(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
            data_gyr = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
            output = model(data_acc.to(device).float(), data_gyr.to(device).float())

            loss = criterion(output, target.to(device).float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
                data_gyr = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
                output = model(data_acc.to(device).float(), data_gyr.to(device).float())
                val_loss += criterion(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %% [markdown]
# ## Multi-Encoder Student Training

# %%
class Encoder_1(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_1, self).__init__()
        self.lstm_1 = nn.LSTM(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.LSTM(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2




class Encoder_2(nn.Module):
    def __init__(self, input_dim, dropout):
        super(Encoder_2, self).__init__()
        self.lstm_1 = nn.GRU(input_dim, 128, bidirectional=True, batch_first=True, dropout=0.0)
        self.lstm_2 = nn.GRU(256, 64, bidirectional=True, batch_first=True, dropout=0.0)
        self.flatten=nn.Flatten()
        self.fc = nn.Linear(128, 32)
        self.dropout_1=nn.Dropout(dropout)
        self.dropout_2=nn.Dropout(dropout)


    def forward(self, x):
        out_1, _ = self.lstm_1(x)
        out_1=self.dropout_1(out_1)
        out_2, _ = self.lstm_2(out_1)
        out_2=self.dropout_2(out_2)

        return out_2

# %%
class GatingModule(nn.Module):
    def __init__(self, input_size):
        super(GatingModule, self).__init__()
        self.gate = nn.Sequential(
            nn.Linear(2*input_size, input_size),
            nn.Sigmoid()
        )

    def forward(self, input1, input2):
        # Apply gating mechanism
        gate_output = self.gate(torch.cat((input1,input2),dim=-1))

        # Scale the inputs based on the gate output
        gated_input1 = input1 * gate_output
        gated_input2 = input2 * (1 - gate_output)

        # Combine the gated inputs
        output = gated_input1 + gated_input2
        return output

# %%
class student_4(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_4, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)

        # x_acc=torch.cat((x_acc_1,x_acc_2),dim=-1)
        # x_gyr=torch.cat((x_gyr_1,x_gyr_2),dim=-1)

        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out

# %%
lr = 0.001
model = student_4(12,12)

mm_student_4 = train_mm_student_4(device, train_loader, val_loader,  lr,40,model, 'model_student_4.pth')
# Out:
# Epoch: 1, time: 7.4457, Training Loss: 52.5473, Validation Loss: 47.9974
# Epoch: 2, time: 7.4765, Training Loss: 41.5571, Validation Loss: 37.0193
# Epoch: 3, time: 7.5917, Training Loss: 33.2955, Validation Loss: 32.4158
# Epoch: 4, time: 7.6655, Training Loss: 29.3687, Validation Loss: 27.9180
# Epoch: 5, time: 7.6683, Training Loss: 26.0560, Validation Loss: 25.9398
# Epoch: 6, time: 7.5923, Training Loss: 23.9781, Validation Loss: 25.5200
# Epoch: 7, time: 7.5578, Training Loss: 22.9013, Validation Loss: 24.3447
# Epoch: 8, time: 7.4864, Training Loss: 21.9953, Validation Loss: 22.9755
# Epoch: 9, time: 7.4668, Training Loss: 20.9066, Validation Loss: 22.5522
# Epoch: 10, time: 7.4641, Training Loss: 20.0219, Validation Loss: 22.1891
# Epoch: 11, time: 7.4366, Training Loss: 19.6825, Validation Loss: 21.9094
# Epoch: 12, time: 7.4289, Training Loss: 18.9960, Validation Loss: 22.1992
# Epoch: 13, time: 7.4419, Training Loss: 17.9294, Validation Loss: 20.2438
# Epoch: 14, time: 7.4756, Training Loss: 17.9338, Validation Loss: 20.1736
# Epoch: 15, time: 7.4984, Training Loss: 17.3383, Validation Loss: 19.4034
# Epoch: 16, time: 7.4837, Training Loss: 16.4015, Validation Loss: 19.1240
# Epoch: 17, time: 7.5392, Training Loss: 16.1347, Validation Loss: 18.4481
# Epoch: 18, time: 7.5415, Training Loss: 15.7440, Validation Loss: 18.8083
# Epoch: 19, time: 7.5159, Training Loss: 15.8213, Validation Loss: 18.4431
# Epoch: 20, time: 7.4967, Training Loss: 14.3882, Validation Loss: 16.9214
# Epoch: 21, time: 7.4938, Training Loss: 14.4938, Validation Loss: 18.0550
# Epoch: 22, time: 7.4825, Training Loss: 14.5961, Validation Loss: 17.1733
# Epoch: 23, time: 7.4715, Training Loss: 13.9452, Validation Loss: 16.2756
# Epoch: 24, time: 7.4676, Training Loss: 13.6196, Validation Loss: 17.5012
# Epoch: 25, time: 7.4756, Training Loss: 13.2681, Validation Loss: 15.6085
# Epoch: 26, time: 7.4980, Training Loss: 12.8278, Validation Loss: 16.5584
# Epoch: 27, time: 7.4785, Training Loss: 13.6440, Validation Loss: 16.7398
# Epoch: 28, time: 7.4772, Training Loss: 13.2012, Validation Loss: 14.3722
# Epoch: 29, time: 7.4790, Training Loss: 12.4964, Validation Loss: 14.7509
# Epoch: 30, time: 7.4757, Training Loss: 11.7219, Validation Loss: 14.0568
# Epoch: 31, time: 7.4802, Training Loss: 11.5804, Validation Loss: 14.1966
# Epoch: 32, time: 7.4720, Training Loss: 11.5517, Validation Loss: 13.7449
# Epoch: 33, time: 7.4825, Training Loss: 11.4992, Validation Loss: 14.2489
# Epoch: 34, time: 7.4973, Training Loss: 11.4029, Validation Loss: 12.5071
# Epoch: 35, time: 7.4829, Training Loss: 11.7680, Validation Loss: 14.0927
# Epoch: 36, time: 7.4820, Training Loss: 11.6908, Validation Loss: 14.8418
# Epoch: 37, time: 7.4790, Training Loss: 10.6173, Validation Loss: 13.0459
# Epoch: 38, time: 7.5013, Training Loss: 9.7210, Validation Loss: 13.3561
# Epoch: 39, time: 7.4986, Training Loss: 11.0921, Validation Loss: 14.1407
# Epoch: 40, time: 7.4896, Training Loss: 11.5242, Validation Loss: 14.1033
# Training time: 300.4632821083069 seconds

# %%
mm_student_4= student_4(12,12)
mm_student_4.load_state_dict(torch.load('model_student_4.pth'))
mm_student_4.to(device)

mm_student_4.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        data_acc=torch.cat((data_acc[:,:,0:9],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:9],data_gyr[:,:,9:12]),dim=-1)
        output = mm_student_4(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_8=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 22.964234077386713
# 19.732727255964416
# 20.859410650030288
#
#
# 0.7240761804803858
# 0.5067318346436456
# 0.4629763047690437
# Mean: 21.185 +/- 1.640
# Mean: 0.565 +/- 0.140

# %% [markdown]
# ## Knowledge+Sensor Distillation

# %%
def train_student_4(device, train_loader, val_loader, learn_rate, EPOCHS, model, filename, teacher):
    if torch.cuda.is_available():
        model.cuda()

    # Defining loss function and optimizer
    criterion_2 = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)

    train_losses = []
    val_losses = []

    running_loss = 0
    start_time = time.time()
    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(EPOCHS):
        epoch_start_time = time.time()
        model.train()
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(train_loader):
            optimizer.zero_grad()
            data_acc_1 = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
            data_gyr_1 = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
            student_output, x_student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())

            with torch.no_grad():
                teacher_output, x_teacher_1 = teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

            loss = criterion_2(student_output, target.to(device).float()) + alpha * criterion_2(student_output, teacher_output) + beta * criterion_2(x_student_1, x_teacher_1)
            loss_1 = criterion_2(student_output, target.to(device))

            loss.backward()
            optimizer.step()

            running_loss += loss_1.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data_acc, data_gyr, target, data_EMG in val_loader:
                data_acc_1 = torch.cat((data_acc[:, :, 0:9], data_acc[:, :, 9:12]), dim=-1)
                data_gyr_1 = torch.cat((data_gyr[:, :, 0:9], data_gyr[:, :, 9:12]), dim=-1)
                output, student_1 = model(data_acc_1.to(device).float(), data_gyr_1.to(device).float())
                val_loss += criterion_2(output, target.to(device).float()).item()

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        epoch_end_time = time.time()
        epoch_training_time = epoch_end_time - epoch_start_time

        print(f"Epoch: {epoch+1}, time: {epoch_training_time:.4f}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        running_loss = 0

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), filename)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Stopping early after {epoch+1} epochs")
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f"Training time: {training_time} seconds")

    # Plotting the training and validation loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
class student_4_KD(nn.Module):
    def __init__(self, input_acc, input_gyr, drop_prob=0.25, w=100):
        super(student_4_KD, self).__init__()
        self.w=w

        self.encoder_1_acc=Encoder_1(input_acc, drop_prob)
        self.encoder_1_gyr=Encoder_1(input_gyr, drop_prob)

        self.encoder_2_acc=Encoder_2(input_acc, drop_prob)
        self.encoder_2_gyr=Encoder_2(input_gyr, drop_prob)

        self.BN_acc= nn.BatchNorm1d(input_acc, affine=False)
        self.BN_gyr= nn.BatchNorm1d(input_gyr, affine=False)

        self.fc_kd=nn.Linear(2*128,2*128)

        self.fc = nn.Linear(2*2*128+128,3)
        self.dropout=nn.Dropout(p=0.05)

        self.gate_1=GatingModule(128)
        self.gate_2=GatingModule(128)


               # Define the gating network
        self.weighted_feat = nn.Sequential(
            nn.Linear(128, 1),
            nn.Sigmoid())

        self.attention=nn.MultiheadAttention(2*128,4,batch_first=True)
        self.gating_net = nn.Sequential(nn.Linear(128*2, 2*128), nn.Sigmoid())
        self.gating_net_1 = nn.Sequential(nn.Linear(2*2*128+128, 2*2*128+128), nn.Sigmoid())


    def forward(self, x_acc, x_gyr):

        x_acc_1=x_acc.view(x_acc.size(0)*x_acc.size(1),x_acc.size(-1))
        x_gyr_1=x_gyr.view(x_gyr.size(0)*x_gyr.size(1),x_gyr.size(-1))

        x_acc_1=self.BN_acc(x_acc_1)
        x_gyr_1=self.BN_gyr(x_gyr_1)

        x_acc_2=x_acc_1.view(-1, self.w, x_acc_1.size(-1))
        x_gyr_2=x_gyr_1.view(-1, self.w, x_gyr_1.size(-1))

        x_acc_1=self.encoder_1_acc(x_acc_2)
        x_gyr_1=self.encoder_1_gyr(x_gyr_2)

        x_acc_2=self.encoder_2_acc(x_acc_2)
        x_gyr_2=self.encoder_2_gyr(x_gyr_2)


        x_acc=self.gate_1(x_acc_1,x_acc_2)
        x_gyr=self.gate_2(x_gyr_1,x_gyr_2)

        x=torch.cat((x_acc,x_gyr),dim=-1)

        x_KD=self.fc_kd(x)

        out_1, attn_output_weights=self.attention(x,x,x)

        gating_weights = self.gating_net(x)
        out_2=gating_weights*x

        weights_1 = self.weighted_feat(x[:,:,0:128])
        weights_2 = self.weighted_feat(x[:,:,128:2*128])
        x_1=weights_1*x[:,:,0:128]
        x_2=weights_2*x[:,:,128:2*128]
        out_3=x_1+x_2


        out=torch.cat((out_1,out_2,out_3),dim=-1)

        gating_weights_1 = self.gating_net_1(out)
        out=gating_weights_1*out

        out=self.fc(out)

        return out,x_KD

# %%
lr = 0.001
student = student_4_KD(12,12)

teacher_trained= teacher(18,18,3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)


student_KD= train_student_4(device, train_loader, val_loader, lr,40, student,'student_4_KD.pth', teacher_trained)
# Out:
# Epoch: 1, time: 12.0742, Training Loss: 52.8405, Validation Loss: 48.7454
# Epoch: 2, time: 12.1643, Training Loss: 41.8246, Validation Loss: 37.3095
# Epoch: 3, time: 12.1732, Training Loss: 32.1741, Validation Loss: 30.0957
# Epoch: 4, time: 11.9674, Training Loss: 27.2432, Validation Loss: 26.5056
# Epoch: 5, time: 11.8499, Training Loss: 24.5886, Validation Loss: 24.5310
# Epoch: 6, time: 11.9644, Training Loss: 22.9704, Validation Loss: 23.3377
# Epoch: 7, time: 11.8145, Training Loss: 21.6098, Validation Loss: 22.7192
# Epoch: 8, time: 11.8524, Training Loss: 20.8920, Validation Loss: 22.0523
# Epoch: 9, time: 11.9796, Training Loss: 20.0223, Validation Loss: 21.4376
# Epoch: 10, time: 11.9611, Training Loss: 19.0918, Validation Loss: 20.7219
# Epoch: 11, time: 11.9832, Training Loss: 18.6012, Validation Loss: 20.2619
# Epoch: 12, time: 11.9492, Training Loss: 17.8139, Validation Loss: 19.5100
# Epoch: 13, time: 11.9260, Training Loss: 17.3244, Validation Loss: 21.0700
# Epoch: 14, time: 11.9111, Training Loss: 17.5035, Validation Loss: 19.4820
# Epoch: 15, time: 11.9506, Training Loss: 16.1617, Validation Loss: 18.5002
# Epoch: 16, time: 11.8920, Training Loss: 15.4918, Validation Loss: 18.4573
# Epoch: 17, time: 11.9205, Training Loss: 15.2317, Validation Loss: 19.1028
# Epoch: 18, time: 11.9362, Training Loss: 15.1596, Validation Loss: 17.8459
# Epoch: 19, time: 11.9567, Training Loss: 14.3179, Validation Loss: 17.4783
# Epoch: 20, time: 12.0055, Training Loss: 14.2923, Validation Loss: 17.6586
# Epoch: 21, time: 11.9772, Training Loss: 13.8582, Validation Loss: 17.1488
# Epoch: 22, time: 11.9842, Training Loss: 13.5139, Validation Loss: 16.1017
# Epoch: 23, time: 12.0133, Training Loss: 12.8775, Validation Loss: 16.3646
# Epoch: 24, time: 11.9192, Training Loss: 12.6561, Validation Loss: 15.7327
# Epoch: 25, time: 11.9225, Training Loss: 12.9475, Validation Loss: 14.9267
# Epoch: 26, time: 11.9166, Training Loss: 12.3311, Validation Loss: 14.9893
# Epoch: 27, time: 11.8991, Training Loss: 11.5642, Validation Loss: 14.8521
# Epoch: 28, time: 11.9032, Training Loss: 11.4308, Validation Loss: 14.3476
# Epoch: 29, time: 11.9039, Training Loss: 11.0823, Validation Loss: 15.0642
# Epoch: 30, time: 11.9134, Training Loss: 12.1361, Validation Loss: 14.8420
# Epoch: 31, time: 11.9594, Training Loss: 11.1473, Validation Loss: 13.3128
# Epoch: 32, time: 11.8959, Training Loss: 10.5362, Validation Loss: 12.9147
# Epoch: 33, time: 11.9019, Training Loss: 10.5324, Validation Loss: 12.2770
# Epoch: 34, time: 11.8866, Training Loss: 10.0970, Validation Loss: 12.6827
# Epoch: 35, time: 11.9063, Training Loss: 10.0994, Validation Loss: 11.9990
# Epoch: 36, time: 11.8977, Training Loss: 10.1782, Validation Loss: 11.5271
# Epoch: 37, time: 11.8944, Training Loss: 10.0331, Validation Loss: 13.1388
# Epoch: 38, time: 11.9084, Training Loss: 10.7226, Validation Loss: 11.8768
# Epoch: 39, time: 11.9206, Training Loss: 9.8544, Validation Loss: 12.2146
# Epoch: 40, time: 11.9409, Training Loss: 9.5573, Validation Loss: 11.5032
# Training time: 478.31470251083374 seconds

# %%
mm_student_1= student_4_KD(12,12)
mm_student_1.load_state_dict(torch.load('student_4_KD.pth'))
mm_student_1.to(device)

mm_student_1.eval()

# iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):

        data_acc=torch.cat((data_acc[:,:,0:9],data_acc[:,:,9:12]),dim=-1)
        data_gyr=torch.cat((data_gyr[:,:,0:9],data_gyr[:,:,9:12]),dim=-1)
        output,student_1 = mm_student_1(data_acc.to(device).float(),data_gyr.to(device).float())
        if i==0:
          yhat_5=output
          test_target=target

        yhat_5=torch.cat((yhat_5,output),dim=0)
        test_target=torch.cat((test_target,target),dim=0)

        # clear memory
        del data_acc, data_gyr, target, data_EMG, output
        torch.cuda.empty_cache()


yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()
print(yhat_4.shape)

rmse, p, Z_1,Z_2,Z_3=RMSE_prediction(yhat_4,test_target,output_dim=3)

ablation_9=np.hstack([rmse,p])
# Out:
# (1988, 100, 3)
# 20.146041384133724
# 18.04957171824744
# 21.90915188223819
#
#
# 0.8001466785654512
# 0.5519066723438935
# 0.49967188227944537
# Mean: 20.035 +/- 1.932
# Mean: 0.617 +/- 0.161

# %%
#load csv
csv_file = '/content/drive/MyDrive/sd_datacollection/subject_10/combined/P010_T001_elbowflexion_fast_combined.csv'
df = pd.read_csv(csv_file)
df.head()

joint_name_list = ["elbow_flex_r","arm_flex_r","arm_add_r"]

# Extract input and target data
input_acc = df[columns_imu_acc].values
input_gyr = df[columns_imu_gyr].values
input_emg = df[['IM EMG4', 'IM EMG5', 'IM EMG6']].values
target_data = df[columns_joints].values

# Create tensors
acc_tensor = torch.tensor(input_acc, dtype=torch.float32).unsqueeze(0)
gyr_tensor = torch.tensor(input_gyr, dtype=torch.float32).unsqueeze(0)
emg_tensor = torch.tensor(input_emg, dtype=torch.float32).unsqueeze(0)
target_tensor = torch.tensor(target_data, dtype=torch.float32).unsqueeze(0)

# Load the trained model
mm_teacher = teacher(18, 18, 3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)
mm_teacher.eval()


window_size = 100
predictions_teacher = []

with torch.no_grad():
    for i in range(0, acc_tensor.shape[1] - window_size + 1, window_size):
        acc_window = acc_tensor[:, i:i + window_size, :].to(device)
        gyr_window = gyr_tensor[:, i:i + window_size, :].to(device)
        emg_window = emg_tensor[:, i:i + window_size, :].to(device)

        output, _ = teacher_trained(acc_window, gyr_window, emg_window)
        predictions_teacher.append(output.cpu().numpy())

# Concatenate predictions along the time dimension to form a continuous time series
predictions_teacher = np.concatenate(predictions_teacher, axis=1)
predictions_teacher = predictions_teacher.reshape(-1, predictions_teacher.shape[-1])

# Ensure shapes are correct
target_tensor_np = target_tensor.cpu().numpy().squeeze(0)
print(f'Predictions shape (teacher): {predictions_teacher.shape}')
print(f'Target shape: {target_tensor_np.shape}')

# Define and initialize the student models
student_models = {
    "model_student_1": student_4(3, 3),
    "student_1_KD": student_4_KD(3, 3),
    "model_student_2": student_4(6, 6),
    "student_2_KD": student_4_KD(6, 6),
    "model_student_3": student_4(9, 9),
    "student_3_KD": student_4_KD(9, 9),
    "model_student_4": student_4(12, 12),
    "student_4_KD": student_4_KD(12, 12),
}

# Collect predictions for each student model
student_predictions = {}

for model_name, model in student_models.items():
    predictions_student = []
    model_path = f"{model_name}.pth"
    model.load_state_dict(torch.load(model_path))
    model.to(device)
    model.eval()

    model_num = int(model_name.split("_")[2]) if "model" in model_name else int(model_name.split("_")[1])
    channels = model_num * 3
    window_size = 100

    with torch.no_grad():
        for i in range(0, acc_tensor.shape[1] - window_size + 1, window_size):
            acc_window = acc_tensor[:, i:i + window_size, :channels].to(device)
            gyr_window = gyr_tensor[:, i:i + window_size, :channels].to(device)
            if "KD" in model_name:
                output, _ = model(acc_window, gyr_window)
            else:
              output = model(acc_window, gyr_window)
            predictions_student.append(output.cpu().numpy())

    predictions_student = np.concatenate(predictions_student, axis=1)
    predictions_student = predictions_student.reshape(-1, predictions_student.shape[-1])
    student_predictions[model_name] = predictions_student




# Plot predictions vs ground truth for each channel
num_channels = predictions_teacher.shape[1]
num_students = len(student_predictions) // 2

for channel in range(num_channels):
    plt.figure(figsize=(10, 6))
    plt.plot(target_tensor_np[:, channel], label='Ground Truth')
    plt.plot(predictions_teacher[:, channel], label='Teacher Predicted')

    plt.title(f'Predicted vs Ground Truth - Channel {joint_name_list[channel]}')
    plt.xlabel('Samples')
    plt.ylabel('Value')
    plt.ylim(-180, 180)
    plt.legend()
    plt.show()

for student in range(1, num_students + 1):
    model_student = f"model_student_{student}"
    student_kd = f"student_{student}_KD"

    for channel in range(num_channels):
        plt.figure(figsize=(10, 6))
        plt.plot(target_tensor_np[:, channel], label='Ground Truth')
        # plt.plot(predictions_teacher[:, channel], label='Teacher Predicted', linestyle='dashed')
        plt.plot(student_predictions[model_student][:, channel], label=f'{model_student} Predicted', linestyle='dotted')
        plt.plot(student_predictions[student_kd][:, channel], label=f'{student_kd} Predicted', linestyle='dashdot')

        plt.title(f'Predicted vs Ground Truth - Channel {joint_name_list[channel]} - Student {student}')
        plt.xlabel('Samples')
        plt.ylabel('Value')
        plt.ylim(-180, 180)

        #make all lines thinner
        for line in plt.gca().get_lines():
            line.set_linewidth(1)
        plt.legend()
        plt.show()
# Out:
# Predictions shape (teacher): (3000, 3)
# Target shape: (3067, 3)

# %%
# Function to process each file and compute errors
def process_file(file_path, teacher_model, student_models):
    df = pd.read_csv(file_path)

    joint_name_list = ["elbow_flex_r", "arm_flex_r", "arm_add_r"]

    # Define the actual column names for imu_acc, imu_gyr, and joints
    columns_imu_acc = ['ACCX1', 'ACCY1', 'ACCZ1', 'ACCX2', 'ACCY2', 'ACCZ2', 'ACCX3', 'ACCY3', 'ACCZ3', 'ACCX4', 'ACCY4', 'ACCZ4', 'ACCX5', 'ACCY5', 'ACCZ5', 'ACCX6', 'ACCY6', 'ACCZ6']
    columns_imu_gyr = ['GYROX1', 'GYROY1', 'GYROZ1', 'GYROX2', 'GYROY2', 'GYROZ2', 'GYROX3', 'GYROY3', 'GYROZ3', 'GYROX4', 'GYROY4', 'GYROZ4', 'GYROX5', 'GYROY5', 'GYROZ5', 'GYROX6', 'GYROY6', 'GYROZ6']
    columns_joints = ['elbow_flex_r', 'arm_flex_r', 'arm_add_r']

    # Check if the test columns are in the DataFrame and use them if available
    columns_imu_acc_test = ['ACCX1', 'ACCY1', 'ACCZ1', 'ACCX2', 'ACCY2', 'ACCZ2', 'ACCX3', 'ACCY3', 'ACCZ3', 'ACCX4', 'ACCY4', 'ACCZ4', 'ACCX5', 'ACCY5', 'ACCZ5', 'ACCX6', 'ACCY6', 'ACCZ6']
    columns_imu_gyr_test = ['GYROX1', 'GYROY1', 'GYROZ1', 'GYROX2', 'GYROY2', 'GYROZ2', 'GYROX3', 'GYROY3', 'GYROZ3', 'GYROX4', 'GYROY4', 'GYROZ4', 'GYROX5', 'GYROY5', 'GYROZ5', 'GYROX6', 'GYROY6', 'GYROZ6']

    if all(col in df.columns for col in columns_imu_acc_test):
        columns_imu_acc = columns_imu_acc_test
    if all(col in df.columns for col in columns_imu_gyr_test):
        columns_imu_gyr = columns_imu_gyr_test

    input_acc = df[columns_imu_acc].values
    input_gyr = df[columns_imu_gyr].values
    input_emg = df[['IM EMG4', 'IM EMG5', 'IM EMG6']].values
    target_data = df[columns_joints].values

    # Create tensors
    acc_tensor = torch.tensor(input_acc, dtype=torch.float32).unsqueeze(0)
    gyr_tensor = torch.tensor(input_gyr, dtype=torch.float32).unsqueeze(0)
    emg_tensor = torch.tensor(input_emg, dtype=torch.float32).unsqueeze(0)
    target_tensor = torch.tensor(target_data, dtype=torch.float32).unsqueeze(0)

    # Perform inference with the teacher model
    window_size = 100
    predictions_teacher = []

    with torch.no_grad():
        for i in range(0, acc_tensor.shape[1] - window_size + 1, window_size):
            acc_window = acc_tensor[:, i:i + window_size, :].to(device)
            gyr_window = gyr_tensor[:, i:i + window_size, :].to(device)
            emg_window = emg_tensor[:, i:i + window_size, :].to(device)

            output, _ = teacher_model(acc_window, gyr_window, emg_window)
            predictions_teacher.append(output.cpu().numpy())

    predictions_teacher = np.concatenate(predictions_teacher, axis=1)
    predictions_teacher = predictions_teacher.reshape(-1, predictions_teacher.shape[-1])
    target_tensor_np = target_tensor.cpu().numpy().squeeze(0)[:predictions_teacher.shape[0]]


    # Collect predictions for each student model
    student_predictions = {}
    for model_name, model in student_models.items():
        predictions_student = []
        model_num = int(model_name.split("_")[2]) if "model" in model_name else int(model_name.split("_")[1])
        channels = model_num * 3

        with torch.no_grad():
            for i in range(0, acc_tensor.shape[1] - window_size + 1, window_size):
                acc_window = acc_tensor[:, i:i + window_size, :channels].to(device)
                gyr_window = gyr_tensor[:, i:i + window_size, :channels].to(device)

                if "KD" in model_name:
                    output, _ = model(acc_window, gyr_window)
                else:
                    output = model(acc_window, gyr_window)
                predictions_student.append(output.cpu().numpy())

        predictions_student = np.concatenate(predictions_student, axis=1)
        predictions_student = predictions_student.reshape(-1, predictions_student.shape[-1])
        student_predictions[model_name] = predictions_student



    # Plot predictions vs ground truth for each channel
    num_channels = predictions_teacher.shape[1]
    num_students = len(student_predictions) // 2

    fig, axes = plt.subplots(1, num_channels, figsize=(5 * num_channels, 5))

    for channel in range(num_channels):
        ax = axes[channel]
        ax.plot(target_tensor_np[:1000, channel], label='Ground Truth')
        ax.plot(predictions_teacher[:1000, channel], label='Teacher Predicted')
        ax.set_title(f'{os.path.basename(file_path)} - Channel {joint_name_list[channel]}')
        ax.set_xlabel('Samples')
        ax.set_ylabel('Value')
        ax.set_ylim(-180, 180)
        ax.legend()

    plt.tight_layout()
    plt.show()

    for student in range(1, num_students + 1):
        fig, axes = plt.subplots(1, num_channels, figsize=(5 * num_channels, 5))


        model_student = f"model_student_{student}"
        student_kd = f"student_{student}_KD"

        for channel in range(num_channels):
            ax = axes[channel]
            ax.plot(target_tensor_np[:, channel], label='Ground Truth')
            # ax.plot(predictions_teacher[:, channel], label='Teacher Predicted')
            ax.plot(student_predictions[model_student][:, channel], label=f'{model_student} Predicted', linestyle='dotted')
            ax.plot(student_predictions[student_kd][:, channel], label=f'{student_kd} Predicted', linestyle='dashdot')
            ax.set_title(f'{os.path.basename(file_path)} - Channel {joint_name_list[channel]} - Student {student}')
            ax.set_xlabel('Samples')
            ax.set_ylabel('Value')
            ax.set_ylim(-180, 180)
            ax.legend()

        plt.tight_layout()
        plt.show()


# Load the teacher model
teacher_trained = teacher(18, 18, 3)
teacher_trained.load_state_dict(torch.load('model_teacher.pth'))
teacher_trained.to(device)
teacher_trained.eval()

# Define and initialize the student models
student_models = {
    "model_student_1": student_4(3, 3),
    "student_1_KD": student_4_KD(3, 3),
    "model_student_2": student_4(6, 6),
    "student_2_KD": student_4_KD(6, 6),
    "model_student_3": student_4(9, 9),
    "student_3_KD": student_4_KD(9, 9),
    "model_student_4": student_4(12, 12),
    "student_4_KD": student_4_KD(12, 12),
}

for model_name, model in student_models.items():
    model_path = f"{model_name}.pth"
    model.load_state_dict(torch.load(model_path))
    model.to(device)
    model.eval()

# Process all files in the combined folder for subject 10
combined_folder_path = '/content/drive/MyDrive/sd_datacollection/subject_10/combined/'
file_paths = glob.glob(os.path.join(combined_folder_path, '*.csv'))

for file_path in file_paths:
    print(f'Processing file: {file_path}')
    process_file(file_path, teacher_trained, student_models)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
subject_combined_folder_path = '/content/drive/MyDrive/sd_datacollection/subject_1/combined/'

# Get all CSV file paths in the subject's combined folder
file_paths = glob.glob(os.path.join(subject_combined_folder_path, '*.csv'))

# Load each file and print its length
for file_path in file_paths:
    df = pd.read_csv(file_path)
    print(f'File: {os.path.basename(file_path)}, Length: {len(df)}')
# Out:
# File: P001_T001_crossbody_fast_combined.csv, Length: 3344
# File: P001_T001_elbowrotation_fast_combined.csv, Length: 3223
# File: P001_T001_overheadreach_max_combined.csv, Length: 3338
# File: P001_T001_elbowrotation_normal_combined.csv, Length: 3211
# File: P001_T001_overheadreach_45_combined.csv, Length: 3210
# File: P001_T001_elbowflexion_normal_combined.csv, Length: 3269
# File: P001_T001_crossbody_slow_combined.csv, Length: 3312
# File: P001_T001_elbowflexion_fast_combined.csv, Length: 3185
# File: P001_T001_armSwing_fast_combined.csv, Length: 3228
# File: P001_T001_elbowrotation_slow_combined.csv, Length: 3365
# File: P001_T001_armSwing_veryfast_combined.csv, Length: 3171
# File: P001_T001_armSwing_normal_combined.csv, Length: 3224
# File: P001_T001_crossbody_normal_combined.csv, Length: 3371
# File: P001_T001_overheadreach_90_combined.csv, Length: 3341
# File: P001_T001_elbowflexion_slow_combined.csv, Length: 3294
# File: P001_T001_armSwing_slow_combined.csv, Length: 3148

# %%
def evaluate_model(model, val_loader, model_num, output_dim=3):
    model.eval()
    yhat_5 = []
    test_target = []

    with torch.no_grad():
        for i, (data_acc, data_gyr, target, data_EMG) in enumerate(val_loader):
            channels = model_num * 3


            try:
              output, _ = model(data_acc[:,:,:channels].to(device).float(), data_gyr[:,:,:channels].to(device).float())
            except:
              output = model(data_acc[:,:,:channels].to(device).float(), data_gyr[:,:,:channels].to(device).float())

            yhat_5.append(output)
            test_target.append(target)

            # clear memory
            del data_acc, data_gyr, target, data_EMG, output
            torch.cuda.empty_cache()

    yhat_4 = torch.cat(yhat_5, dim=0).detach().cpu().numpy()
    test_target = torch.cat(test_target, dim=0).detach().cpu().numpy()
    print(yhat_4.shape)

    rmse, p, Z_1, Z_2, Z_3 = RMSE_prediction(yhat_4, test_target, output_dim=output_dim)
    return np.hstack([rmse, p])

# Load and evaluate each student model
student_models = {
    "model_student_1": student_4(3, 3),
    "student_1_KD": student_4_KD(3, 3),
    "model_student_2": student_4(6, 6),
    "student_2_KD": student_4_KD(6, 6),
    "model_student_3": student_4(9, 9),
    "student_3_KD": student_4_KD(9, 9),
    "model_student_4": student_4(12, 12),
    "student_4_KD": student_4_KD(12, 12),
}

for model_name, model in student_models.items():
    model_path = f"{model_name}.pth"
    model.load_state_dict(torch.load(model_path))
    model.to(device)

    model_num = int(model_name.split("_")[2]) if "model" in model_name else int(model_name.split("_")[1])

    print(f'Evaluating {model_name}')
    ablation_results = evaluate_model(model, val_loader, model_num)
    print(f'{model_name} results: {ablation_results}')
# Out:
# Evaluating model_student_1
# (1174, 100, 3)
# 15.94103709754039
# 12.075931058851845
# 14.517867953822936
#
#
# 0.7874052172911158
# 0.8210466683163485
# 0.7931029756737364
# Mean: 14.178 +/- 1.955
# Mean: 0.801 +/- 0.018
# model_student_1 results: [15.9410371  12.07593106 14.51786795  0.78740522  0.82104667  0.79310298]
# Evaluating student_1_KD
# (1174, 100, 3)
# 15.98282414800293
# 12.37469291521191
# 15.289840969426516
#
#
# 0.7860253538127974
# 0.8114071590119016
# 0.7680227302991888
# Mean: 14.549 +/- 1.915
# Mean: 0.788 +/- 0.022
# student_1_KD results: [15.98282415 12.37469292 15.28984097  0.78602535  0.81140716  0.76802273]
# Evaluating model_student_2
# (1174, 100, 3)
# 27.267743486950074
# 21.023284779086772
# 27.30385097061304
#
#
# 0.33887557023551024
# 0.3716236613496792
# 0.16842942622352516
# Mean: 25.198 +/- 3.616
# Mean: 0.293 +/- 0.109
# model_student_2 results: [27.26774349 21.02328478 27.30385097  0.33887557  0.37162366  0.16842943]
# Evaluating student_2_KD
# (1174, 100, 3)
# 26.57179937077171
# 21.643750374695006
# 28.546578423456033
#
#
# 0.3414264910666524
# 0.32000823645300747
# 0.08499672019545754
# Mean: 25.587 +/- 3.555
# Mean: 0.249 +/- 0.142
# student_2_KD results: [26.57179937 21.64375037 28.54657842  0.34142649  0.32000824  0.08499672]
# Evaluating model_student_3
# (1174, 100, 3)
# 22.344692071673563
# 20.005353750354658
# 28.425911670441074
#
#
# 0.646171780125482
# 0.4254964656321903
# 0.20964678735014322
# Mean: 23.592 +/- 4.347
# Mean: 0.427 +/- 0.218
# model_student_3 results: [22.34469207 20.00535375 28.42591167  0.64617178  0.42549647  0.20964679]
# Evaluating student_3_KD
# (1174, 100, 3)
# 25.44936283670973
# 20.377254961996215
# 29.847615163675627
#
#
# 0.5541752149193833
# 0.38546067683675295
# 0.11595845526631798
# Mean: 25.225 +/- 4.739
# Mean: 0.352 +/- 0.221
# student_3_KD results: [25.44936284 20.37725496 29.84761516  0.55417521  0.38546068  0.11595846]
# Evaluating model_student_4
# (1174, 100, 3)
# 4.1321448083888725
# 5.361497517512101
# 5.475787369185884
#
#
# 0.9873398604314871
# 0.9674172951285578
# 0.9733455838082021
# Mean: 4.990 +/- 0.745
# Mean: 0.976 +/- 0.010
# model_student_4 results: [4.13214481 5.36149752 5.47578737 0.98733986 0.9674173  0.97334558]
# Evaluating student_4_KD
# (1174, 100, 3)
# 3.6124446367738177
# 4.926779094271527
# 5.459869709147888
#
#
# 0.9902175023643216
# 0.9727107611010964
# 0.9738217402101088
# Mean: 4.666 +/- 0.951
# Mean: 0.979 +/- 0.010
# student_4_KD results: [3.61244464 4.92677909 5.45986971 0.9902175  0.97271076 0.97382174]

# %%
# Load the trained model
mm_teacher = teacher(18, 18, 3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)
mm_teacher.eval()

# Initialize variables to store predictions and targets
yhat_5 = None
test_target = None

# Iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(val_loader):
        output, x_1 = mm_teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

        if i == 0:
            yhat_5 = output
            test_target = target
        else:
            yhat_5 = torch.cat((yhat_5, output), dim=0)
            test_target = torch.cat((test_target, target), dim=0)

        # Clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()

# Convert to numpy arrays for further processing
yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()

print(f'Predicted shape: {yhat_4.shape}')
print(f'Target shape: {test_target.shape}')

rmse, p, Z_1, Z_2, Z_3 = RMSE_prediction(yhat_4, test_target, output_dim=3)

# Define joint names
joint_name_list = ["elbow_flex_r", "arm_flex_r", "arm_add_r"]

# Number of samples to plot from the first dimension
m_samples = 10

# Plot predicted vs ground truth for each channel
num_dims = yhat_4.shape[2]

for sample_idx in range(m_samples):
    fig, axes = plt.subplots(1, num_dims, figsize=(15, 5))

    for dim in range(num_dims):
        ax = axes[dim]
        ground_truth = test_target[sample_idx, :, dim]
        predicted = yhat_4[sample_idx, :, dim]

        ax.plot(ground_truth, label='Ground Truth')
        ax.plot(predicted, label='Predicted', linestyle='dashed')

        # Calculate y-axis limits centered around the mean with a width of 100
        y_min = min(np.min(ground_truth), np.min(predicted))
        y_max = max(np.max(ground_truth), np.max(predicted))
        y_center = (y_min + y_max) / 2
        y_window = 200
        ax.set_ylim(y_center - y_window / 2, y_center + y_window / 2)

        ax.set_title(f'Sample {sample_idx + 1} - {joint_name_list[dim]}')
        ax.set_xlabel('Samples')
        ax.set_ylabel('Value')
        ax.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Predicted shape: (1174, 100, 3)
# Target shape: (1174, 100, 3)
# 3.5984152428978358
# 5.110330241222034
# 5.6359243552790375
#
#
# 0.9902881428698964
# 0.9708093797246673
# 0.9717828180736114
# Mean: 4.782 +/- 1.058
# Mean: 0.978 +/- 0.011

# %%
# Load the trained model
mm_teacher = teacher(18, 18, 3)
mm_teacher.load_state_dict(torch.load('model_teacher.pth'))
mm_teacher.to(device)
mm_teacher.eval()

# Initialize variables to store predictions and targets
yhat_5 = None
test_target = None

# Iterate through batches of test data
with torch.no_grad():
    for i, (data_acc, data_gyr, target, data_EMG) in enumerate(test_loader):
        output, x_1 = mm_teacher(data_acc.to(device).float(), data_gyr.to(device).float(), data_EMG.to(device).float())

        if i == 0:
            yhat_5 = output
            test_target = target
        else:
            yhat_5 = torch.cat((yhat_5, output), dim=0)
            test_target = torch.cat((test_target, target), dim=0)

        # Clear memory
        del data_acc, data_gyr, data_EMG, target, output
        torch.cuda.empty_cache()

# Convert to numpy arrays for further processing
yhat_4 = yhat_5.detach().cpu().numpy()
test_target = test_target.detach().cpu().numpy()

print(f'Predicted shape: {yhat_4.shape}')
print(f'Target shape: {test_target.shape}')

rmse, p, Z_1, Z_2, Z_3 = RMSE_prediction(yhat_4, test_target, output_dim=3)

# Define joint names
joint_name_list = ["elbow_flex_r", "arm_flex_r", "arm_add_r"]

# Number of samples to plot from the first dimension
m_samples = 10

# Plot predicted vs ground truth for each channel
num_dims = yhat_4.shape[2]

for sample_idx in range(m_samples):
    fig, axes = plt.subplots(1, num_dims, figsize=(15, 5))

    for dim in range(num_dims):
        ax = axes[dim]
        ground_truth = test_target[sample_idx, :, dim]
        predicted = yhat_4[sample_idx, :, dim]

        ax.plot(ground_truth, label='Ground Truth')
        ax.plot(predicted, label='Predicted', linestyle='dashed')

        # Calculate y-axis limits centered around the mean with a width of 100
        y_min = min(np.min(ground_truth), np.min(predicted))
        y_max = max(np.max(ground_truth), np.max(predicted))
        y_center = (y_min + y_max) / 2
        y_window = 200
        ax.set_ylim(y_center - y_window / 2, y_center + y_window / 2)

        ax.set_title(f'Sample {sample_idx + 1} - {joint_name_list[dim]}')
        ax.set_xlabel('Samples')
        ax.set_ylabel('Value')
        ax.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Predicted shape: (1924, 100, 3)
# Target shape: (1924, 100, 3)
# 22.63404242425088
# 15.953500969305711
# 16.54577061173045
#
#
# 0.8199360722564775
# 0.6913589144497405
# 0.6787128681160891
# Mean: 18.378 +/- 3.698
# Mean: 0.730 +/- 0.078
